# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# georgetown sh
# arraial do cabo br
# punta arenas cl
# sinnamary gf
# zarubino ru
# khurianwala pk
# san angelo us
# vaini to
# ushuaia ar
# sur om
# olafsvik is
# zhigansk ru
# dongtai cn
# ushuaia ar
# benguela ao
# avarua ck
# butaritari ki
# busselton au
# punta arenas cl
# yeppoon au
# vila do maio cv
# albany au
# wangaratta au
# hasaki jp
# okhotsk ru
# fortuna us
# warmbad na
# kysyl-syr ru
# kaitangata nz
# pevek ru
# bethel us
# ushuaia ar
# avarua ck
# tefe br
# khatanga ru
# rikitea pf
# ranau my
# ribeira grande pt
# padrauna in
# belushya guba ru
# avarua ck
# cape town za
# la ronge ca
# atuona pf
# itaqui br
# ancud cl
# jamestown sh
# hasaki jp
# mumbwa zm
# saldanha za
# kaitangata nz
# busselton au
# port elizabeth za
# provideniya ru
# ancud cl
# punta arenas cl
# barrow us
# nanortalik gl
# rikitea pf
# turek pl
# lasa cn
# hirara jp
# arlit ne
# rikitea pf
# olenino ru
# mar del plata ar
# murgab tm
# rikitea pf
# khatanga ru
# illoqqortoormiut gl
# katangli ru
# tazovskiy ru
# moose factory ca
# tasiilaq gl
# asino ru
# tautira pf
# norman wells ca
# yar-sale ru
# el naranjo mx
# luderitz na
# rikitea pf
# chuy uy
# jamestown sh
# berezna ua
# albany au
# trang th
# komsomolets ru
# weyburn ca
# rikitea pf
# busselton au
# port macquarie au
# georgetown sh
# kodiak us
# caravelas br
# new norfolk au
# sernur ru
# punta arenas cl
# saskylakh ru
# saldanha za
# georgetown sh
# bambous virieux mu
# tias es
# coruripe br
# bilibino ru
# umkomaas za
# gewane et
# saint george bm
# dzerzhinskoye ru
# guerrero negro mx
# port elizabeth za
# bredasdorp za
# saskylakh ru
# yeppoon au
# albany au
# hasaki jp
# punta arenas cl
# seoul kr
# manzhouli cn
# barrow us
# castro cl
# manicore br
# pevek ru
# bluff nz
# taoudenni ml
# mar del plata ar
# maungaturoto nz
# yellowknife ca
# hermanus za
# yellowknife ca
# kirakira sb
# mataura pf
# ushuaia ar
# fortuna us
# shieli kz
# baykit ru
# klaksvik fo
# auki sb
# kyra ru
# albany au
# bengkulu id
# pevek ru
# thompson ca
# belushya guba ru
# vaini to
# georgetown sh
# glendive us
# bengkulu id
# luderitz na
# cape town za
# atar mr
# yulara au
# vao nc
# nikolskoye ru
# roald no
# houma us
# port alfred za
# busselton au
# alyangula au
# taolanaro mg
# kaseda jp
# mgandu tz
# new norfolk au
# saint george us
# karla ee
# hithadhoo mv
# chitipa mw
# cape town za
# hilo us
# new norfolk au
# new norfolk au
# yellowknife ca
# tuktoyaktuk ca
# carnarvon au
# vicuna cl
# puerto ayora ec
# bredasdorp za
# vila velha br
# labuhan id
# tautira pf
# puerto ayora ec
# mar del plata ar
# rikitea pf
# taolanaro mg
# saint-philippe re
# puerto ayora ec
# la ronge ca
# nemuro jp
# saint-joseph re
# sola vu
# havre-saint-pierre ca
# vaini to
# marzuq ly
# arraial do cabo br
# hamilton bm
# upernavik gl
# punta arenas cl
# qaanaaq gl
# sao filipe cv
# bolungarvik is
# kangaatsiaq gl
# saskylakh ru
# new norfolk au
# albany au
# busselton au
# kamenka ru
# jamestown us
# salamiyah sy
# auki sb
# baghdad iq
# melfi td
# carnarvon au
# punta arenas cl
# sfantu gheorghe ro
# jamestown sh
# albany au
# barrow us
# hobart au
# nanortalik gl
# camacupa ao
# punta arenas cl
# rikitea pf
# menongue ao
# lasa cn
# voh nc
# gravdal no
# dikson ru
# deputatskiy ru
# busselton au
# hithadhoo mv
# orange au
# uglovka ru
# morong ph
# albany au
# rikitea pf
# chokurdakh ru
# georgetown sh
# busselton au
# barentsburg sj
# port alfred za
# sisimiut gl
# kasongo-lunda cd
# saskylakh ru
# pucallpa pe
# upernavik gl
# pevek ru
# east london za
# cagayan de tawi-tawi ph
# shubarshi kz
# komsomolskiy ru
# maneadero mx
# hermanus za
# fairhope us
# coquimbo cl
# hobart au
# erenhot cn
# nishihara jp
# ostrovnoy ru
# hermanus za
# taolanaro mg
# katsuura jp
# kavieng pg
# uruacu br
# busselton au
# avarua ck
# kargasok ru
# albany au
# hami cn
# hilo us
# hilo us
# cochrane ca
# muros es
# amapa br
# kamenskoye ru
# samusu ws
# sao benedito do rio preto br
# rikitea pf
# yar-sale ru
# tawau my
# klaksvik fo
# mar del plata ar
# berea us
# coquimbo cl
# hobart au
# busselton au
# medea dz
# illoqqortoormiut gl
# isangel vu
# rikitea pf
# butaritari ki
# saldanha za
# bambous virieux mu
# chuy uy
# cherskiy ru
# scarborough gb
# iona us
# mataura pf
# butaritari ki
# qazvin ir
# busselton au
# perth au
# wattegama lk
# viedma ar
# bafra tr
# vuktyl ru
# ushuaia ar
# lebu cl
# tumannyy ru
# barentsburg sj
# siyabuswa za
# cape town za
# saskylakh ru
# codrington ag
# avarua ck
# dikson ru
# ushuaia ar
# barentsburg sj
# pevek ru
# atuona pf
# jamestown sh
# mataura pf
# vaini to
# natal br
# illoqqortoormiut gl
# gat ly
# jamestown sh
# gudari in
# nacala mz
# boguchany ru
# hermanus za
# kuzovatovo ru
# airai pw
# fort smith us
# kathu za
# busselton au
# rikitea pf
# namibe ao
# kieta pg
# mar del plata ar
# arraial do cabo br
# hobart au
# samalaeulu ws
# labutta mm
# busselton au
# port elizabeth za
# atuona pf
# bredasdorp za
# busselton au
# new norfolk au
# sorland no
# qaanaaq gl
# tsiroanomandidy mg
# chuy uy
# yellowknife ca
# hilo us
# fredericksburg us
# batagay-alyta ru
# sambava mg
# kushima jp
# clinton us
# bambous virieux mu
# opuwo na
# adre td
# butaritari ki
# belushya guba ru
# manta ec
# kapaa us
# fortuna us
# saskylakh ru
# sola vu
# port elizabeth za
# busselton au
# ca mau vn
# labrea br
# tasiilaq gl
# gulu ug
# kavaratti in
# mataura pf
# nanortalik gl
# fort smith us
# east london za
# rikitea pf
# bredasdorp za
# cape town za
# beringovskiy ru
# san fernando mx
# kavieng pg
# nizhniy kuranakh ru
# sobolevo ru
# qaanaaq gl
# aktau kz
# mataura pf
# rikitea pf
# alice springs au
# carnarvon au
# mazagao br
# mombetsu jp
# kapaa us
# ancud cl
# port lincoln au
# sao filipe cv
# nizwa om
# barrow us
# barentsburg sj
# torbay ca
# punta arenas cl
# georgetown sh
# vallenar cl
# luderitz na
# tuktoyaktuk ca
# cam ranh vn
# port alfred za
# albany au
# belushya guba ru
# sentyabrskiy ru
# bredasdorp za
# qaanaaq gl
# busselton au
# chokurdakh ru
# rikitea pf
# beloha mg
# chifeng cn
# ushuaia ar
# leningradskiy ru
# la ronge ca
# akureyri is
# mar del plata ar
# hermanus za
# esperance au
# ushuaia ar
# arraial do cabo br
# taolanaro mg
# broome au
# mataura pf
# ribeira grande pt
# hermanus za
# gravdal no
# albany au
# mataura pf
# longyearbyen sj
# tasiilaq gl
# severo-kurilsk ru
# airai pw
# mataura pf
# hilo us
# rikitea pf
# sentyabrskiy ru
# nome us
# juneau us
# sao geraldo do araguaia br
# jamestown sh
# saldanha za
# rikitea pf
# bredasdorp za
# bluff nz
# huarmey pe
# rikitea pf
# albany au
# tahoua ne
# vaini to
# nizhneyansk ru
# illoqqortoormiut gl
# tautira pf
# alice springs au
# bethel us
# isangel vu
# dire ml
# rikitea pf
# burica pa
# sindand af
# muros es
# hobart au
# klaksvik fo
# busselton au
# hervey bay au
# bredasdorp za
# busselton au
# albany au
# lebu cl
# mataura pf
# lebu cl
# tervel bg
# jamestown sh
# coahuayana mx
# grindavik is
# dingle ie
# taoudenni ml
# san quintin mx
# sataua ws
# illoqqortoormiut gl
# mogadishu so
# mayo ca
# tasiilaq gl
# vaini to
# sabang id
# port macquarie au
# puerto baquerizo moreno ec
# yellowknife ca
# cape town za
# nikolskoye ru
# arraial do cabo br
# katsuura jp
# lebu cl
# bredasdorp za
# yellowknife ca
# palauig ph
# ribeira grande pt
# jabiru au
# olinda br
# bethel us
# east london za
# punta arenas cl
# husavik is
# portland au
# carnarvon au
# mount gambier au
# new norfolk au
# richard toll sn
# srednekolymsk ru
# punta arenas cl
# bredasdorp za
# codrington ag
# touros br
# illoqqortoormiut gl
# hobart au
# elliot lake ca
# dingle ie
# yacuiba bo
# new norfolk au
# port alfred za
# yerbogachen ru
# bambous virieux mu
# hilo us
# tuatapere nz
# ushuaia ar
# upernavik gl
# katsuura jp
# lebu cl
# cape town za
# hobart au
# adrar dz
# barentsburg sj
# dawson creek ca
# jamestown sh
# ushuaia ar
# karratha au
# sola vu
# albany au
# norman wells ca
# carnarvon au
# kapaa us
# zhezkazgan kz
# illoqqortoormiut gl
# butaritari ki
# mexico us
# alihe cn
# castro cl
# albany au
# edeleny hu
# uwayl sd
# camacha pt
# port alfred za
# ushuaia ar
# brentwood us
# saleaula ws
# vaini to
# mannargudi in
# kaputa zm
# cidreira br
# ushuaia ar
# bredasdorp za
# albany au
# jamestown sh
# albany au
# lebu cl
# bodden town ky
# punta arenas cl
# brejo br
# hilo us
# atuona pf
# punta arenas cl
# taolanaro mg
# hermanus za
# coolum beach au
# yulara au
# shakhtinsk kz
# porto murtinho br
# bluff nz
# butaritari ki
# sentyabrskiy ru
# talnakh ru
# comodoro rivadavia ar
# saint pete beach us
# ushuaia ar
# port alfred za
# khatanga ru
# kismayo so
# kikuyu ke
# vila franca do campo pt
# russell nz
# joigny fr
# rikitea pf
# norman wells ca
# saint george bm
# gazni af
# taolanaro mg
# maracas br
# minsk by
# blytheville us
# kapaa us
# luzhou cn
# tsaratanana mg
# kununurra au
# hobart au
# tiksi ru
# tabou ci
# kayerkan ru
# ucluelet ca
# sept-iles ca
# krasnoufimsk ru
# busselton au
# oranjestad aw
# zuenoula ci
# srednekolymsk ru
# rikitea pf
# esperance au
# verkh-tula ru
# cape town za
# mecca sa
# hobart au
# airai pw
# alpena us
# narsaq gl
# bethel us
# kavaratti in
# busselton au
# mataura pf
# qaanaaq gl
# yellowknife ca
# ambilobe mg
# ushuaia ar
# kruisfontein za
# tiksi ru
# bredasdorp za
# ilulissat gl
# nizhneyansk ru
# rikitea pf
# bathsheba bb
# aitape pg
# rikitea pf
# cherskiy ru
# east london za
# surt ly
# narsaq gl
# meulaboh id
# saskylakh ru
# samusu ws
# bluff nz
# mataura pf
# castro cl
# timaru nz
# puerto ayora ec
# vaini to
# albany au
# sorland no
# pevek ru
# jamestown sh
# svetlyy ru
# punta arenas cl
# mataura pf
# mlowo tz
# marsaxlokk mt
# albany au
# punta arenas cl
# kashi cn
# thompson ca
# bredasdorp za
# kushmurun kz
# kapaa us
# touros br
# avarua ck
# bluff nz
# lebu cl
# bredasdorp za
# hermanus za
# kaitangata nz
# lebu cl
# ust-nera ru
# hobart au
# mataura pf
# nome us
# constitucion mx
# alofi nu
# tadine nc
# cairns au
# christchurch nz
# ushuaia ar
# mar del plata ar
# sentyabrskiy ru
# kahului us
# avarua ck
# hobart au
# asadabad af
# umm kaddadah sd
# verkhoyansk ru
# tiksi ru
# albany au
# manturovo ru
# puerto baquerizo moreno ec
# gazanjyk tm
# remedios pa
# saldanha za
# boende cd
# tasiilaq gl
# avarua ck
# meulaboh id
# thompson ca
# cartagena es
# chapais ca
# atuona pf
# tasiilaq gl
# mar del plata ar
# puerto quijarro bo
# mys shmidta ru
# upernavik gl
# lasa cn
# ushuaia ar
# katsuura jp
# avarua ck
# xadani mx
# les cayes ht
# port elizabeth za
# ushuaia ar
# chokurdakh ru
# menongue ao
# busselton au
# cabo san lucas mx
# lagoa pt
# mar del plata ar
# ushuaia ar
# port elizabeth za
# sivaki ru
# attawapiskat ca
# port alfred za
# mataura pf
# tiznit ma
# atuona pf
# floriano br
# abu samrah qa
# havoysund no
# tuatapere nz
# cherskiy ru
# laguna br
# busselton au
# albany au
# dahuk iq
# albany au
# bethel us
# pafos cy
# illoqqortoormiut gl
# rikitea pf
# albany au
# rikitea pf
# kapaa us
# breves br
# punta arenas cl
# cape town za
# saint george bm
# cape town za
# bluff nz
# srednekolymsk ru
# busselton au
# ushuaia ar
# castro cl
# boundiali ci
# taolanaro mg
# caravelas br
# veseloyarsk ru
# mataura pf
# kapaa us
# butaritari ki
# yellowknife ca
# redcliffe zw
# albany au
# east london za
# ostersund se
# ushuaia ar
# vaini to
# clyde river ca
# talaya ru
# norman wells ca
# gradignan fr
# ciudad bolivar ve
# chokurdakh ru
# omboue ga
# port alfred za
# verkhoyansk ru
# katsuura jp
# boa vista br
# kodiak us
# tiksi ru
# bilibino ru
# longyearbyen sj
# sechura pe
# albany au
# airai pw
# albany au
# bredasdorp za
# meulaboh id
# albany au
# carmo do rio claro br
# avarua ck
# butaritari ki
# fort william gb
# cherskiy ru
# atuona pf
# ilinskiy ru
# clyde river ca
# tuktoyaktuk ca
# saleaula ws
# cape town za
# ushuaia ar
# kavieng pg
# chokurdakh ru
# hobart au
# ituni gy
# taolanaro mg
# mys shmidta ru
# bethel us

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 764

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ac2e4786cf2f619d410e21ee95a035a

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ac2e4786cf2f619d410e21ee95a035a&q=Boston

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Weather Condition": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | georgetown
# Processing Record 2 of Set 1 | arraial do cabo
# Processing Record 3 of Set 1 | punta arenas
# Processing Record 4 of Set 1 | sinnamary
# Processing Record 5 of Set 1 | zarubino
# Processing Record 6 of Set 1 | khurianwala
# City not found. Skipping...
# Processing Record 7 of Set 1 | san angelo
# Processing Record 8 of Set 1 | vaini
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | sur
# Processing Record 11 of Set 1 | olafsvik
# Processing Record 12 of Set 1 | zhigansk
# Processing Record 13 of Set 1 | dongtai
# Processing Record 14 of Set 1 | benguela
# Processing Record 15 of Set 1 | avarua
# Processing Record 16 of Set 1 | butaritari
# Processing Record 17 of Set 1 | busselton
# Processing Record 18 of Set 1 | yeppoon
# Processing Record 19 of Set 1 | vila do maio
# Processing Record 20 of Set 1 | albany
# Processing Record 21 of Set 1 | wangaratta
# Processing Record 22 of Set 1 | hasaki
# Processing Record 23 of Set 1 | okhotsk
# Processing Record 24 of Set 1 | fortuna
# Processing Record 25 of Set 1 | warmbad
# Processing Record 26 of Set 1 | kysyl-syr
# Processing Record 27 of Set 1 | kaitangata
# Processing Record 28 of Set 1 | pevek
# Processing Record 29 of Set 1 | bethel
# Processing Record 30 of Set 1 | tefe
# Processing Record 31 of Set 1 | khatanga
# Processing Record 32 of Set 1 | rikitea
# Processing Record 33 of Set 1 | ranau
# Processing Record 34 of Set 1 | ribeira grande
# Processing Record 35 of Set 1 | padrauna
# Processing Record 36 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 37 of Set 1 | cape town
# Processing Record 38 of Set 1 | la ronge
# Processing Record 39 of Set 1 | atuona
# Processing Record 40 of Set 1 | itaqui
# Processing Record 41 of Set 1 | ancud
# Processing Record 42 of Set 1 | jamestown
# Processing Record 43 of Set 1 | mumbwa
# Processing Record 44 of Set 1 | saldanha
# Processing Record 45 of Set 1 | port elizabeth
# Processing Record 46 of Set 1 | provideniya
# Processing Record 47 of Set 1 | barrow
# Processing Record 48 of Set 1 | nanortalik
# Processing Record 49 of Set 1 | turek
# Processing Record 50 of Set 1 | lasa
# Processing Record 1 of Set 2 | hirara
# Processing Record 2 of Set 2 | arlit
# Processing Record 3 of Set 2 | olenino
# Processing Record 4 of Set 2 | mar del plata
# Processing Record 5 of Set 2 | murgab
# Processing Record 6 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 7 of Set 2 | katangli
# Processing Record 8 of Set 2 | tazovskiy
# Processing Record 9 of Set 2 | moose factory
# Processing Record 10 of Set 2 | tasiilaq
# Processing Record 11 of Set 2 | asino
# Processing Record 12 of Set 2 | tautira
# Processing Record 13 of Set 2 | norman wells
# Processing Record 14 of Set 2 | yar-sale
# Processing Record 15 of Set 2 | el naranjo
# Processing Record 16 of Set 2 | luderitz
# Processing Record 17 of Set 2 | chuy
# Processing Record 18 of Set 2 | berezna
# Processing Record 19 of Set 2 | trang
# Processing Record 20 of Set 2 | komsomolets
# Processing Record 21 of Set 2 | weyburn
# Processing Record 22 of Set 2 | port macquarie
# Processing Record 23 of Set 2 | kodiak
# Processing Record 24 of Set 2 | caravelas
# Processing Record 25 of Set 2 | new norfolk
# Processing Record 26 of Set 2 | sernur
# Processing Record 27 of Set 2 | saskylakh
# Processing Record 28 of Set 2 | bambous virieux
# Processing Record 29 of Set 2 | tias
# Processing Record 30 of Set 2 | coruripe
# Processing Record 31 of Set 2 | bilibino
# Processing Record 32 of Set 2 | umkomaas
# Processing Record 33 of Set 2 | gewane
# Processing Record 34 of Set 2 | saint george
# Processing Record 35 of Set 2 | dzerzhinskoye
# Processing Record 36 of Set 2 | guerrero negro
# Processing Record 37 of Set 2 | bredasdorp
# Processing Record 38 of Set 2 | seoul
# Processing Record 39 of Set 2 | manzhouli
# Processing Record 40 of Set 2 | castro
# Processing Record 41 of Set 2 | manicore
# Processing Record 42 of Set 2 | bluff
# Processing Record 43 of Set 2 | taoudenni
# Processing Record 44 of Set 2 | maungaturoto
# Processing Record 45 of Set 2 | yellowknife
# Processing Record 46 of Set 2 | hermanus
# Processing Record 47 of Set 2 | kirakira
# Processing Record 48 of Set 2 | mataura
# Processing Record 49 of Set 2 | shieli
# Processing Record 50 of Set 2 | baykit
# Processing Record 1 of Set 3 | klaksvik
# Processing Record 2 of Set 3 | auki
# Processing Record 3 of Set 3 | kyra
# Processing Record 4 of Set 3 | bengkulu
# Processing Record 5 of Set 3 | thompson
# Processing Record 6 of Set 3 | glendive
# Processing Record 7 of Set 3 | atar
# Processing Record 8 of Set 3 | yulara
# Processing Record 9 of Set 3 | vao
# Processing Record 10 of Set 3 | nikolskoye
# Processing Record 11 of Set 3 | roald
# Processing Record 12 of Set 3 | houma
# Processing Record 13 of Set 3 | port alfred
# Processing Record 14 of Set 3 | alyangula
# Processing Record 15 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 16 of Set 3 | kaseda
# Processing Record 17 of Set 3 | mgandu
# Processing Record 18 of Set 3 | karla
# Processing Record 19 of Set 3 | hithadhoo
# Processing Record 20 of Set 3 | chitipa
# Processing Record 21 of Set 3 | hilo
# Processing Record 22 of Set 3 | tuktoyaktuk
# Processing Record 23 of Set 3 | carnarvon
# Processing Record 24 of Set 3 | vicuna
# Processing Record 25 of Set 3 | puerto ayora
# Processing Record 26 of Set 3 | vila velha
# Processing Record 27 of Set 3 | labuhan
# Processing Record 28 of Set 3 | saint-philippe
# Processing Record 29 of Set 3 | nemuro
# Processing Record 30 of Set 3 | saint-joseph
# Processing Record 31 of Set 3 | sola
# Processing Record 32 of Set 3 | havre-saint-pierre
# Processing Record 33 of Set 3 | marzuq
# Processing Record 34 of Set 3 | hamilton
# Processing Record 35 of Set 3 | upernavik
# Processing Record 36 of Set 3 | qaanaaq
# Processing Record 37 of Set 3 | noumea
# Processing Record 38 of Set 3 | boende
# Processing Record 39 of Set 3 | cravo norte
# Processing Record 40 of Set 3 | morondava
# Processing Record 41 of Set 3 | pasighat
# Processing Record 42 of Set 3 | nikolayevsk-na-amure
# Processing Record 43 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 44 of Set 3 | makat
# Processing Record 45 of Set 3 | badou
# Processing Record 46 of Set 3 | iqaluit
# Processing Record 47 of Set 3 | yunjinghong
# City not found. Skipping...
# Processing Record 48 of Set 3 | ontario
# Processing Record 49 of Set 3 | camacha
# Processing Record 50 of Set 3 | nayoro
# Processing Record 1 of Set 4 | mount gambier
# Processing Record 2 of Set 4 | port blair
# Processing Record 3 of Set 4 | beloha
# Processing Record 4 of Set 4 | miyazu
# Processing Record 5 of Set 4 | sao joao da barra
# Processing Record 6 of Set 4 | puerto colombia
# Processing Record 7 of Set 4 | constitucion
# Processing Record 8 of Set 4 | rodrigues alves
# Processing Record 9 of Set 4 | oktyabrskiy
# Processing Record 10 of Set 4 | dikson
# Processing Record 11 of Set 4 | amga
# Processing Record 12 of Set 4 | goure
# Processing Record 13 of Set 4 | etchoropo
# Processing Record 14 of Set 4 | tsienyane
# City not found. Skipping...
# Processing Record 15 of Set 4 | milford
# Processing Record 16 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 17 of Set 4 | wilmington
# Processing Record 18 of Set 4 | peniche
# Processing Record 19 of Set 4 | lebu
# Processing Record 20 of Set 4 | kawalu
# Processing Record 21 of Set 4 | poum
# Processing Record 22 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 23 of Set 4 | kiunga
# Processing Record 24 of Set 4 | torbay
# Processing Record 25 of Set 4 | husavik
# Processing Record 26 of Set 4 | kapaa
# Processing Record 27 of Set 4 | kavieng
# Processing Record 28 of Set 4 | lodhran
# Processing Record 29 of Set 4 | bouna
# Processing Record 30 of Set 4 | mingyue
# Processing Record 31 of Set 4 | caucasia
# Processing Record 32 of Set 4 | hobyo
# Processing Record 33 of Set 4 | salalah
# Processing Record 34 of Set 4 | axim
# Processing Record 35 of Set 4 | bilma
# Processing Record 36 of Set 4 | komsomolskiy
# Processing Record 37 of Set 4 | aklavik
# Processing Record 38 of Set 4 | kailua
# Processing Record 39 of Set 4 | kerouane
# Processing Record 40 of Set 4 | hobart
# Processing Record 41 of Set 4 | tuatapere
# Processing Record 42 of Set 4 | talnakh
# Processing Record 43 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 44 of Set 4 | dongying
# Processing Record 45 of Set 4 | meulaboh
# Processing Record 46 of Set 4 | lavrentiya
# Processing Record 47 of Set 4 | sisimiut
# Processing Record 48 of Set 4 | ola
# Processing Record 49 of Set 4 | horta
# Processing Record 50 of Set 4 | hokitika
# Processing Record 1 of Set 5 | gurgan
# City not found. Skipping...
# Processing Record 2 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 3 of Set 5 | bolshaya vishera
# City not found. Skipping...
# Processing Record 4 of Set 5 | udachnyy
# Processing Record 5 of Set 5 | karratha
# Processing Record 6 of Set 5 | oranjemund
# Processing Record 7 of Set 5 | nome
# Processing Record 8 of Set 5 | bandarbeyla
# Processing Record 9 of Set 5 | zhigalovo
# Processing Record 10 of Set 5 | shepsi
# Processing Record 11 of Set 5 | redmond
# Processing Record 12 of Set 5 | genhe
# Processing Record 13 of Set 5 | progreso
# Processing Record 14 of Set 5 | praia
# Processing Record 15 of Set 5 | codrington
# Processing Record 16 of Set 5 | cherskiy
# Processing Record 17 of Set 5 | kuytun
# Processing Record 18 of Set 5 | gravdal
# Processing Record 19 of Set 5 | mancio lima
# Processing Record 20 of Set 5 | samalaeulu
# City not found. Skipping...
# Processing Record 21 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 22 of Set 5 | musoma
# Processing Record 23 of Set 5 | cabo san lucas
# Processing Record 24 of Set 5 | sidney
# Processing Record 25 of Set 5 | candelaria
# Processing Record 26 of Set 5 | cayenne
# Processing Record 27 of Set 5 | east london
# Processing Record 28 of Set 5 | arbroath
# Processing Record 29 of Set 5 | victoria
# Processing Record 30 of Set 5 | uvira
# Processing Record 31 of Set 5 | batagay
# Processing Record 32 of Set 5 | san cristobal
# Processing Record 33 of Set 5 | prestice
# Processing Record 34 of Set 5 | sao filipe
# Processing Record 35 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 36 of Set 5 | kangaatsiaq
# Processing Record 37 of Set 5 | kamenka
# Processing Record 38 of Set 5 | salamiyah
# Processing Record 39 of Set 5 | baghdad
# Processing Record 40 of Set 5 | melfi
# Processing Record 41 of Set 5 | sfantu gheorghe
# Processing Record 42 of Set 5 | camacupa
# Processing Record 43 of Set 5 | menongue
# Processing Record 44 of Set 5 | voh
# Processing Record 45 of Set 5 | deputatskiy
# Processing Record 46 of Set 5 | orange
# Processing Record 47 of Set 5 | uglovka
# Processing Record 48 of Set 5 | morong
# Processing Record 49 of Set 5 | chokurdakh
# Processing Record 50 of Set 5 | kasongo-lunda
# Processing Record 1 of Set 6 | pucallpa
# Processing Record 2 of Set 6 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 3 of Set 6 | shubarshi
# Processing Record 4 of Set 6 | maneadero
# Processing Record 5 of Set 6 | fairhope
# Processing Record 6 of Set 6 | coquimbo
# Processing Record 7 of Set 6 | erenhot
# Processing Record 8 of Set 6 | nishihara
# Processing Record 9 of Set 6 | ostrovnoy
# Processing Record 10 of Set 6 | katsuura
# Processing Record 11 of Set 6 | uruacu
# Processing Record 12 of Set 6 | kargasok
# Processing Record 13 of Set 6 | hami
# Processing Record 14 of Set 6 | cochrane
# Processing Record 15 of Set 6 | muros
# Processing Record 16 of Set 6 | amapa
# Processing Record 17 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 18 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 19 of Set 6 | sao benedito do rio preto
# Processing Record 20 of Set 6 | tawau
# Processing Record 21 of Set 6 | berea
# Processing Record 22 of Set 6 | medea
# Processing Record 23 of Set 6 | isangel
# Processing Record 24 of Set 6 | scarborough
# Processing Record 25 of Set 6 | iona
# Processing Record 26 of Set 6 | qazvin
# Processing Record 27 of Set 6 | perth
# Processing Record 28 of Set 6 | wattegama
# Processing Record 29 of Set 6 | viedma
# Processing Record 30 of Set 6 | bafra
# Processing Record 31 of Set 6 | vuktyl
# Processing Record 32 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 33 of Set 6 | siyabuswa
# Processing Record 34 of Set 6 | natal
# Processing Record 35 of Set 6 | gat
# Processing Record 36 of Set 6 | gudari
# Processing Record 37 of Set 6 | nacala
# Processing Record 38 of Set 6 | boguchany
# Processing Record 39 of Set 6 | kuzovatovo
# Processing Record 40 of Set 6 | airai
# Processing Record 41 of Set 6 | fort smith
# Processing Record 42 of Set 6 | kathu
# Processing Record 43 of Set 6 | namibe
# Processing Record 44 of Set 6 | kieta
# Processing Record 45 of Set 6 | labutta
# City not found. Skipping...
# Processing Record 46 of Set 6 | sorland
# Processing Record 47 of Set 6 | tsiroanomandidy
# Processing Record 48 of Set 6 | fredericksburg
# Processing Record 49 of Set 6 | batagay-alyta
# Processing Record 50 of Set 6 | sambava
# Processing Record 1 of Set 7 | kushima
# Processing Record 2 of Set 7 | clinton
# Processing Record 3 of Set 7 | opuwo
# Processing Record 4 of Set 7 | adre
# Processing Record 5 of Set 7 | manta
# Processing Record 6 of Set 7 | ca mau
# Processing Record 7 of Set 7 | labrea
# Processing Record 8 of Set 7 | gulu
# Processing Record 9 of Set 7 | kavaratti
# Processing Record 10 of Set 7 | beringovskiy
# Processing Record 11 of Set 7 | san fernando
# Processing Record 12 of Set 7 | nizhniy kuranakh
# Processing Record 13 of Set 7 | sobolevo
# Processing Record 14 of Set 7 | aktau
# Processing Record 15 of Set 7 | alice springs
# Processing Record 16 of Set 7 | mazagao
# Processing Record 17 of Set 7 | oshikango
# Processing Record 18 of Set 7 | dzhebariki-khaya
# Processing Record 19 of Set 7 | crawley
# Processing Record 20 of Set 7 | coos bay
# Processing Record 21 of Set 7 | san rafael del sur
# Processing Record 22 of Set 7 | mahebourg
# Processing Record 23 of Set 7 | sanming
# Processing Record 24 of Set 7 | sinkat
# City not found. Skipping...
# Processing Record 25 of Set 7 | port hedland
# Processing Record 26 of Set 7 | mehamn
# Processing Record 27 of Set 7 | longyearbyen
# Processing Record 28 of Set 7 | nahrin
# Processing Record 29 of Set 7 | balaghat
# Processing Record 30 of Set 7 | mosquera
# Processing Record 31 of Set 7 | filadelfia
# Processing Record 32 of Set 7 | bar harbor
# Processing Record 33 of Set 7 | dunedin
# Processing Record 34 of Set 7 | necochea
# Processing Record 35 of Set 7 | sochi
# Processing Record 36 of Set 7 | novopokrovka
# Processing Record 37 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 38 of Set 7 | havelock
# Processing Record 39 of Set 7 | aksu
# Processing Record 40 of Set 7 | venado tuerto
# Processing Record 41 of Set 7 | sahrak
# City not found. Skipping...
# Processing Record 42 of Set 7 | bayeux
# Processing Record 43 of Set 7 | zaragoza
# Processing Record 44 of Set 7 | saint-louis
# Processing Record 45 of Set 7 | atasu
# Processing Record 46 of Set 7 | port hawkesbury
# Processing Record 47 of Set 7 | saint-georges
# Processing Record 48 of Set 7 | narsaq
# Processing Record 49 of Set 7 | changping
# Processing Record 50 of Set 7 | markala
# Processing Record 1 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 2 of Set 8 | jalu
# Processing Record 3 of Set 8 | diapaga
# Processing Record 4 of Set 8 | druzhba
# Processing Record 5 of Set 8 | puerto del rosario
# Processing Record 6 of Set 8 | chalmette
# Processing Record 7 of Set 8 | tabatinga
# Processing Record 8 of Set 8 | buenos aires
# Processing Record 9 of Set 8 | outlook
# Processing Record 10 of Set 8 | dingle
# Processing Record 11 of Set 8 | imeni poliny osipenko
# Processing Record 12 of Set 8 | inta
# Processing Record 13 of Set 8 | surt
# Processing Record 14 of Set 8 | bella union
# Processing Record 15 of Set 8 | pimentel
# Processing Record 16 of Set 8 | rundu
# Processing Record 17 of Set 8 | sergeyevka
# Processing Record 18 of Set 8 | leavenworth
# Processing Record 19 of Set 8 | trairi
# Processing Record 20 of Set 8 | zalantun
# Processing Record 21 of Set 8 | college
# Processing Record 22 of Set 8 | port hardy
# Processing Record 23 of Set 8 | bathsheba
# Processing Record 24 of Set 8 | smidovich
# Processing Record 25 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 26 of Set 8 | kudahuvadhoo
# Processing Record 27 of Set 8 | hovd
# Processing Record 28 of Set 8 | kompaniyivka
# Processing Record 29 of Set 8 | tandil
# Processing Record 30 of Set 8 | bubaque
# Processing Record 31 of Set 8 | dabat
# Processing Record 32 of Set 8 | gari
# Processing Record 33 of Set 8 | havoysund
# Processing Record 34 of Set 8 | caxito
# Processing Record 35 of Set 8 | chagoda
# Processing Record 36 of Set 8 | morant bay
# Processing Record 37 of Set 8 | rajula
# Processing Record 38 of Set 8 | mwinilunga
# Processing Record 39 of Set 8 | grindavik
# Processing Record 40 of Set 8 | katherine
# Processing Record 41 of Set 8 | dalvik
# Processing Record 42 of Set 8 | chernyshevskiy
# Processing Record 43 of Set 8 | kladovo
# Processing Record 44 of Set 8 | valparaiso
# Processing Record 45 of Set 8 | gavle
# Processing Record 46 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 47 of Set 8 | san patricio
# Processing Record 48 of Set 8 | adrar
# Processing Record 49 of Set 8 | faanui
# Processing Record 50 of Set 8 | faya
# Processing Record 1 of Set 9 | souillac
# Processing Record 2 of Set 9 | trinidad
# Processing Record 3 of Set 9 | ukiah
# Processing Record 4 of Set 9 | padang
# Processing Record 5 of Set 9 | banda aceh
# Processing Record 6 of Set 9 | viligili
# City not found. Skipping...
# Processing Record 7 of Set 9 | geraldton
# Processing Record 8 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 9 of Set 9 | san jeronimo
# Processing Record 10 of Set 9 | tres picos
# Processing Record 11 of Set 9 | kahului
# Processing Record 12 of Set 9 | tessalit
# Processing Record 13 of Set 9 | bull savanna
# Processing Record 14 of Set 9 | sabha
# Processing Record 15 of Set 9 | pietersburg
# Processing Record 16 of Set 9 | palu
# Processing Record 17 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 18 of Set 9 | gayeri
# Processing Record 19 of Set 9 | mount darwin
# Processing Record 20 of Set 9 | kondoa
# Processing Record 21 of Set 9 | saint-pierre
# Processing Record 22 of Set 9 | novobureyskiy
# Processing Record 23 of Set 9 | srednekolymsk
# Processing Record 24 of Set 9 | burica
# City not found. Skipping...
# Processing Record 25 of Set 9 | kushiro
# Processing Record 26 of Set 9 | kalanguy
# Processing Record 27 of Set 9 | tommot
# Processing Record 28 of Set 9 | novovasylivka
# Processing Record 29 of Set 9 | west bay
# Processing Record 30 of Set 9 | borogontsy
# Processing Record 31 of Set 9 | fort nelson
# Processing Record 32 of Set 9 | bur gabo
# City not found. Skipping...
# Processing Record 33 of Set 9 | bairnsdale
# Processing Record 34 of Set 9 | laguna de perlas
# Processing Record 35 of Set 9 | tiksi
# Processing Record 36 of Set 9 | azul
# Processing Record 37 of Set 9 | itiuba
# Processing Record 38 of Set 9 | paita
# Processing Record 39 of Set 9 | amuntai
# Processing Record 40 of Set 9 | henties bay
# Processing Record 41 of Set 9 | kandrian
# Processing Record 42 of Set 9 | kybartai
# Processing Record 43 of Set 9 | sydney
# Processing Record 44 of Set 9 | los llanos de aridane
# Processing Record 45 of Set 9 | mercedes
# Processing Record 46 of Set 9 | solnechnyy
# Processing Record 47 of Set 9 | itarema
# Processing Record 48 of Set 9 | sibolga
# Processing Record 49 of Set 9 | strai
# Processing Record 50 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 1 of Set 10 | tuy hoa
# Processing Record 2 of Set 10 | novikovo
# Processing Record 3 of Set 10 | fairbanks
# Processing Record 4 of Set 10 | abu samrah
# Processing Record 5 of Set 10 | christchurch
# Processing Record 6 of Set 10 | andenes
# Processing Record 7 of Set 10 | leshukonskoye
# Processing Record 8 of Set 10 | port lincoln
# Processing Record 9 of Set 10 | zhanaozen
# Processing Record 10 of Set 10 | port-gentil
# Processing Record 11 of Set 10 | waddan
# Processing Record 12 of Set 10 | nalut
# Processing Record 13 of Set 10 | mombetsu
# Processing Record 14 of Set 10 | nizwa
# Processing Record 15 of Set 10 | vallenar
# Processing Record 16 of Set 10 | cam ranh
# Processing Record 17 of Set 10 | chifeng
# Processing Record 18 of Set 10 | leningradskiy
# Processing Record 19 of Set 10 | akureyri
# Processing Record 20 of Set 10 | esperance
# Processing Record 21 of Set 10 | broome
# Processing Record 22 of Set 10 | severo-kurilsk
# Processing Record 23 of Set 10 | juneau
# Processing Record 24 of Set 10 | sao geraldo do araguaia
# Processing Record 25 of Set 10 | huarmey
# Processing Record 26 of Set 10 | tahoua
# Processing Record 27 of Set 10 | dire
# Processing Record 28 of Set 10 | sindand
# City not found. Skipping...
# Processing Record 29 of Set 10 | hervey bay
# Processing Record 30 of Set 10 | tervel
# Processing Record 31 of Set 10 | coahuayana
# Processing Record 32 of Set 10 | san quintin
# Processing Record 33 of Set 10 | sataua
# City not found. Skipping...
# Processing Record 34 of Set 10 | mogadishu
# Processing Record 35 of Set 10 | mayo
# Processing Record 36 of Set 10 | sabang
# Processing Record 37 of Set 10 | puerto baquerizo moreno
# Processing Record 38 of Set 10 | palauig
# Processing Record 39 of Set 10 | jabiru
# City not found. Skipping...
# Processing Record 40 of Set 10 | olinda
# Processing Record 41 of Set 10 | portland
# Processing Record 42 of Set 10 | richard toll
# City not found. Skipping...
# Processing Record 43 of Set 10 | touros
# Processing Record 44 of Set 10 | elliot lake
# Processing Record 45 of Set 10 | yacuiba
# Processing Record 46 of Set 10 | yerbogachen
# Processing Record 47 of Set 10 | dawson creek
# Processing Record 48 of Set 10 | zhezkazgan
# Processing Record 49 of Set 10 | mexico
# Processing Record 50 of Set 10 | alihe
# Processing Record 1 of Set 11 | edeleny
# Processing Record 2 of Set 11 | uwayl
# City not found. Skipping...
# Processing Record 3 of Set 11 | brentwood
# Processing Record 4 of Set 11 | mannargudi
# Processing Record 5 of Set 11 | kaputa
# Processing Record 6 of Set 11 | cidreira
# Processing Record 7 of Set 11 | bodden town
# Processing Record 8 of Set 11 | brejo
# Processing Record 9 of Set 11 | coolum beach
# Processing Record 10 of Set 11 | shakhtinsk
# Processing Record 11 of Set 11 | porto murtinho
# Processing Record 12 of Set 11 | rocha
# Processing Record 13 of Set 11 | ishigaki
# Processing Record 14 of Set 11 | kribi
# Processing Record 15 of Set 11 | san nicolas
# Processing Record 16 of Set 11 | shahpur
# Processing Record 17 of Set 11 | bonavista
# Processing Record 18 of Set 11 | hohhot
# Processing Record 19 of Set 11 | zonguldak
# Processing Record 20 of Set 11 | flinders
# Processing Record 21 of Set 11 | maragogi
# Processing Record 22 of Set 11 | sao felix do xingu
# Processing Record 23 of Set 11 | ponta do sol
# Processing Record 24 of Set 11 | vigrestad
# Processing Record 25 of Set 11 | lata
# Processing Record 26 of Set 11 | barawe
# City not found. Skipping...
# Processing Record 27 of Set 11 | clyde river
# Processing Record 28 of Set 11 | barbar
# City not found. Skipping...
# Processing Record 29 of Set 11 | owen sound
# Processing Record 30 of Set 11 | ginda
# Processing Record 31 of Set 11 | alotau
# City not found. Skipping...
# Processing Record 32 of Set 11 | immokalee
# Processing Record 33 of Set 11 | charagua
# Processing Record 34 of Set 11 | bosaso
# Processing Record 35 of Set 11 | mogochin
# City not found. Skipping...
# Processing Record 36 of Set 11 | safford
# Processing Record 37 of Set 11 | karpogory
# Processing Record 38 of Set 11 | qui nhon
# Processing Record 39 of Set 11 | idrinskoye
# Processing Record 40 of Set 11 | darnah
# Processing Record 41 of Set 11 | san andres
# Processing Record 42 of Set 11 | kedrovyy
# Processing Record 43 of Set 11 | karawang
# Processing Record 44 of Set 11 | gondanglegi
# Processing Record 45 of Set 11 | kenai
# Processing Record 46 of Set 11 | lahad datu
# Processing Record 47 of Set 11 | kuminskiy
# Processing Record 48 of Set 11 | gimli
# Processing Record 49 of Set 11 | pacific grove
# Processing Record 50 of Set 11 | brownsville
# Processing Record 1 of Set 12 | fukue
# Processing Record 2 of Set 12 | ibra
# Processing Record 3 of Set 12 | gweta
# Processing Record 4 of Set 12 | iquique
# Processing Record 5 of Set 12 | smiths falls
# Processing Record 6 of Set 12 | puerto madryn
# Processing Record 7 of Set 12 | laguna
# Processing Record 8 of Set 12 | boisar
# Processing Record 9 of Set 12 | ilulissat
# Processing Record 10 of Set 12 | bardiyah
# Processing Record 11 of Set 12 | ciro marina
# Processing Record 12 of Set 12 | lamu
# Processing Record 13 of Set 12 | krishnanagar
# Processing Record 14 of Set 12 | norsup
# Processing Record 15 of Set 12 | aquin
# Processing Record 16 of Set 12 | newport
# Processing Record 17 of Set 12 | kitgum
# Processing Record 18 of Set 12 | san policarpo
# Processing Record 19 of Set 12 | tera
# Processing Record 20 of Set 12 | half moon bay
# Processing Record 21 of Set 12 | spokane
# Processing Record 22 of Set 12 | merauke
# Processing Record 23 of Set 12 | pangnirtung
# Processing Record 24 of Set 12 | attawapiskat
# City not found. Skipping...
# Processing Record 25 of Set 12 | grand gaube
# Processing Record 26 of Set 12 | sinjar
# Processing Record 27 of Set 12 | vestmannaeyjar
# Processing Record 28 of Set 12 | comodoro rivadavia
# Processing Record 29 of Set 12 | saint pete beach
# Processing Record 30 of Set 12 | kismayo
# Processing Record 31 of Set 12 | kikuyu
# Processing Record 32 of Set 12 | vila franca do campo
# Processing Record 33 of Set 12 | russell
# Processing Record 34 of Set 12 | joigny
# Processing Record 35 of Set 12 | gazni
# City not found. Skipping...
# Processing Record 36 of Set 12 | maracas
# Processing Record 37 of Set 12 | minsk
# Processing Record 38 of Set 12 | blytheville
# Processing Record 39 of Set 12 | luzhou
# Processing Record 40 of Set 12 | tsaratanana
# Processing Record 41 of Set 12 | kununurra
# Processing Record 42 of Set 12 | tabou
# Processing Record 43 of Set 12 | kayerkan
# Processing Record 44 of Set 12 | ucluelet
# Processing Record 45 of Set 12 | sept-iles
# Processing Record 46 of Set 12 | krasnoufimsk
# Processing Record 47 of Set 12 | oranjestad
# Processing Record 48 of Set 12 | zuenoula
# Processing Record 49 of Set 12 | verkh-tula
# Processing Record 50 of Set 12 | mecca
# Processing Record 1 of Set 13 | alpena
# Processing Record 2 of Set 13 | ambilobe
# Processing Record 3 of Set 13 | kruisfontein
# Processing Record 4 of Set 13 | aitape
# Processing Record 5 of Set 13 | timaru
# Processing Record 6 of Set 13 | svetlyy
# Processing Record 7 of Set 13 | mlowo
# Processing Record 8 of Set 13 | marsaxlokk
# Processing Record 9 of Set 13 | kashi
# Processing Record 10 of Set 13 | kushmurun
# Processing Record 11 of Set 13 | ust-nera
# Processing Record 12 of Set 13 | alofi
# Processing Record 13 of Set 13 | tadine
# Processing Record 14 of Set 13 | cairns
# Processing Record 15 of Set 13 | asadabad
# Processing Record 16 of Set 13 | umm kaddadah
# Processing Record 17 of Set 13 | verkhoyansk
# Processing Record 18 of Set 13 | manturovo
# Processing Record 19 of Set 13 | gazanjyk
# Processing Record 20 of Set 13 | remedios
# Processing Record 21 of Set 13 | cartagena
# Processing Record 22 of Set 13 | chapais
# Processing Record 23 of Set 13 | puerto quijarro
# Processing Record 24 of Set 13 | xadani
# City not found. Skipping...
# Processing Record 25 of Set 13 | les cayes
# Processing Record 26 of Set 13 | lagoa
# Processing Record 27 of Set 13 | sivaki
# Processing Record 28 of Set 13 | tiznit
# Processing Record 29 of Set 13 | floriano
# Processing Record 30 of Set 13 | dahuk
# Processing Record 31 of Set 13 | pafos
# Processing Record 32 of Set 13 | breves
# Processing Record 33 of Set 13 | boundiali
# Processing Record 34 of Set 13 | veseloyarsk
# Processing Record 35 of Set 13 | redcliffe
# Processing Record 36 of Set 13 | ostersund
# Processing Record 37 of Set 13 | georgiyevka
# Processing Record 38 of Set 13 | palana
# Processing Record 39 of Set 13 | iracoubo
# Processing Record 40 of Set 13 | dezful
# Processing Record 41 of Set 13 | kinablangan
# Processing Record 42 of Set 13 | samsun
# Processing Record 43 of Set 13 | champerico
# Processing Record 44 of Set 13 | andevoranto
# City not found. Skipping...
# Processing Record 45 of Set 13 | vostok
# Processing Record 46 of Set 13 | aktash
# Processing Record 47 of Set 13 | zyryanka
# Processing Record 48 of Set 13 | mingaora
# Processing Record 49 of Set 13 | ruidoso
# Processing Record 50 of Set 13 | nouakchott
# Processing Record 1 of Set 14 | kazanskoye
# Processing Record 2 of Set 14 | kirovskiy
# Processing Record 3 of Set 14 | miri
# Processing Record 4 of Set 14 | simpang
# Processing Record 5 of Set 14 | uyuni
# Processing Record 6 of Set 14 | aberystwyth
# Processing Record 7 of Set 14 | samarai
# Processing Record 8 of Set 14 | santa cruz
# Processing Record 9 of Set 14 | bahir dar
# Processing Record 10 of Set 14 | mitu
# Processing Record 11 of Set 14 | conceicao do araguaia
# Processing Record 12 of Set 14 | muborak
# Processing Record 13 of Set 14 | tawnat
# City not found. Skipping...
# Processing Record 14 of Set 14 | nevers
# Processing Record 15 of Set 14 | juegang
# Processing Record 16 of Set 14 | kano
# Processing Record 17 of Set 14 | karamea
# City not found. Skipping...
# Processing Record 18 of Set 14 | konevo
# Processing Record 19 of Set 14 | ondorhaan
# City not found. Skipping...
# Processing Record 20 of Set 14 | general roca
# Processing Record 21 of Set 14 | les trois-ilets
# Processing Record 22 of Set 14 | bowen
# Processing Record 23 of Set 14 | dongsheng
# Processing Record 24 of Set 14 | kattivakkam
# Processing Record 25 of Set 14 | gejiu
# Processing Record 26 of Set 14 | saravan
# Processing Record 27 of Set 14 | launceston
# Processing Record 28 of Set 14 | shimsk
# Processing Record 29 of Set 14 | rolim de moura
# City not found. Skipping...
# Processing Record 30 of Set 14 | hofn
# Processing Record 31 of Set 14 | angoche
# Processing Record 32 of Set 14 | argostolion
# Processing Record 33 of Set 14 | vanimo
# Processing Record 34 of Set 14 | burgeo
# Processing Record 35 of Set 14 | kloulklubed
# Processing Record 36 of Set 14 | khani
# Processing Record 37 of Set 14 | antalaha
# Processing Record 38 of Set 14 | tabuk
# Processing Record 39 of Set 14 | haines junction
# Processing Record 40 of Set 14 | gopalganj
# Processing Record 41 of Set 14 | ceska ves
# Processing Record 42 of Set 14 | qaqortoq
# Processing Record 43 of Set 14 | banjar
# Processing Record 44 of Set 14 | riaba
# City not found. Skipping...
# Processing Record 45 of Set 14 | sauda
# Processing Record 46 of Set 14 | dumas
# Processing Record 47 of Set 14 | bireun
# Processing Record 48 of Set 14 | zabol
# Processing Record 49 of Set 14 | stange
# Processing Record 50 of Set 14 | candawaga
# City not found. Skipping...
# Processing Record 1 of Set 15 | oistins
# Processing Record 2 of Set 15 | varnamo
# Processing Record 3 of Set 15 | pisco
# Processing Record 4 of Set 15 | quelimane
# Processing Record 5 of Set 15 | nyeri
# Processing Record 6 of Set 15 | lake havasu city
# Processing Record 7 of Set 15 | bud
# Processing Record 8 of Set 15 | yanam
# Processing Record 9 of Set 15 | punta alta
# Processing Record 10 of Set 15 | turukhansk
# Processing Record 11 of Set 15 | deep river
# Processing Record 12 of Set 15 | lorengau
# Processing Record 13 of Set 15 | barcelos
# Processing Record 14 of Set 15 | tymovskoye
# Processing Record 15 of Set 15 | seminole
# Processing Record 16 of Set 15 | saint anthony
# Processing Record 17 of Set 15 | izobilnyy
# Processing Record 18 of Set 15 | mergui
# City not found. Skipping...
# Processing Record 19 of Set 15 | kastamonu
# Processing Record 20 of Set 15 | magadan
# Processing Record 21 of Set 15 | sagua la grande
# Processing Record 22 of Set 15 | sokolka
# Processing Record 23 of Set 15 | cam pha
# City not found. Skipping...
# Processing Record 24 of Set 15 | kingman
# Processing Record 25 of Set 15 | ahipara
# Processing Record 26 of Set 15 | mazara del vallo
# Processing Record 27 of Set 15 | otjiwarongo
# Processing Record 28 of Set 15 | mihai viteazu
# Processing Record 29 of Set 15 | marsa matruh
# Processing Record 30 of Set 15 | mackay
# Processing Record 31 of Set 15 | talakan
# Processing Record 32 of Set 15 | eskil
# Processing Record 33 of Set 15 | delano
# Processing Record 34 of Set 15 | margate
# Processing Record 35 of Set 15 | aksarka
# Processing Record 36 of Set 15 | koungou
# Processing Record 37 of Set 15 | mweka
# Processing Record 38 of Set 15 | lar
# Processing Record 39 of Set 15 | harper
# Processing Record 40 of Set 15 | setubal
# Processing Record 41 of Set 15 | ife
# Processing Record 42 of Set 15 | vizianagaram
# Processing Record 43 of Set 15 | sao jose da coroa grande
# Processing Record 44 of Set 15 | avera
# Processing Record 45 of Set 15 | flin flon
# Processing Record 46 of Set 15 | tarudant
# City not found. Skipping...
# Processing Record 47 of Set 15 | dzhusaly
# City not found. Skipping...
# Processing Record 48 of Set 15 | sechura
# Processing Record 49 of Set 15 | katobu
# Processing Record 50 of Set 15 | tungkang
# City not found. Skipping...
# Processing Record 1 of Set 16 | simbahan
# Processing Record 2 of Set 16 | maputo
# Processing Record 3 of Set 16 | berlin
# Processing Record 4 of Set 16 | agadez
# Processing Record 5 of Set 16 | vanderhoof
# Processing Record 6 of Set 16 | talaya
# Processing Record 7 of Set 16 | gradignan
# Processing Record 8 of Set 16 | ciudad bolivar
# Processing Record 9 of Set 16 | omboue
# Processing Record 10 of Set 16 | boa vista
# Processing Record 11 of Set 16 | carmo do rio claro
# Processing Record 12 of Set 16 | fort william
# Processing Record 13 of Set 16 | ilinskiy
# Processing Record 14 of Set 16 | ituni
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data
# Out:
# [{'City': 'Georgetown',
#   'Lat': 5.41,
#   'Lng': 100.34,
#   'Max Temp': 80.6,
#   'Humidity': 94,
#   'Cloudiness': 20,
#   'Wind Speed': 2.24,
#   'Country': 'MY',
#   'Date': '2020-07-31 01:09:04',
#   'Weather Condition': 'few clouds'},
#  {'City': 'Arraial Do Cabo',
#   'Lat': -22.97,
#   'Lng': -42.03,
#   'Max Temp': 67.41,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 14.81,
#   'Country': 'BR',
#   'Date': '2020-07-31 01:13:31',
#   'Weather Condition': 'overcast clouds'},
#  {'City': 'Punta Arenas',
#   'Lat': -53.15,
#   'Lng': -70.92,
#   'Max Temp': 35.6,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 14.99,
#   'Country': 'CL',
#   'Date': '2020-07-31 01:13:31',
#   'Weather Condition': 'overcast clouds'},
#  {'City': 'Sinnamary',
#   'Lat': 5.38,
#   'Lng': -52.95,
#   'Max Temp': 78.57,
#   'Humidity': 80,
#   'Cloudiness': 17,
#   'Wind Speed': 4.85,
#   'Country': 'GF',
#   'Date': '2020-07-31 01:13:31',
#   'Weather Condition': 'few clouds'},
#  {'City': 'Zarubino',
#   'Lat': 42.63,
#   'Lng': 131.09,
#   'Max Temp': 74.05,
#   'Humidity': 78,
#   'Cloudiness': 81,
#   'Wind Speed': 4.72,
#   'Country': 'RU',
#   'Date': '2020-07-31 01:13:31',
#   'Weather Condition': 'broken clouds'},
#  {'City': 'San Angelo',
#   'Lat': 31.46,
#   'Lng': -100.44,
#   'Max Temp': 96.8,
#   'Humidity': 32,
#   'Cloudiness': 1,
#   'Wind Speed': 16.11,
#   'Country': 'US',
#   'Date': '2020-07-31 01:11:12',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Vaini',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 75.2,
#   'Humidity': 69,
#   'Cloudiness': 40,
#   'Wind Speed': 13.87,
#   'Country': 'TO',
#   'Date': '2020-07-31 01:13:31',
#   'Weather Condition': 'scattered clouds'},
#  {'City': 'Ushuaia',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 33.8,
#   'Humidity': 74,
#   'Cloudiness': 20,
#   'Wind Speed': 5.82,
#   'Country': 'AR',
#   'Date': '2020-07-31 01:13:31',
#   'Weather Condition': 'few clouds'},
#  {'City': 'Sur',
#   'Lat': 22.57,
#   'Lng': 59.53,
#   'Max Temp': 90.07,
#   'Humidity': 57,
#   'Cloudiness': 23,
#   'Wind Speed': 5.17,
#   'Country': 'OM',
#   'Date': '2020-07-31 01:13:31',
#   'Weather Condition': 'few clouds'},
#  {'City': 'Olafsvik',
#   'Lat': 64.89,
#   'Lng': -23.71,
#   'Max Temp': 50.58,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 8.75,
#   'Country': 'IS',
#   'Date': '2020-07-31 01:13:31',
#   'Weather Condition': 'overcast clouds'},
#  {'City': 'Zhigansk',
#   'Lat': 66.77,
#   'Lng': 123.37,
#   'Max Temp': 58.32,
#   'Humidity': 60,
#   'Cloudiness': 0,
#   'Wind Speed': 12.57,
#   'Country': 'RU',
#   'Date': '2020-07-31 01:13:31',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Dongtai',
#   'Lat': 32.85,
#   'Lng': 120.31,
#   'Max Temp': 78.75,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 3.62,
#   'Country': 'CN',
#   'Date': '2020-07-31 01:15:16',
#   'Weather Condition': 'moderate rain'},
#  {'City': 'Benguela',
#   'Lat': -12.58,
#   'Lng': 13.41,
#   'Max Temp': 68.52,
#   'Humidity': 86,
#   'Cloudiness': 0,
#   'Wind Speed': 5.61,
#   'Country': 'AO',
#   'Date': '2020-07-31 01:18:58',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Avarua',
#   'Lat': -21.21,
#   'Lng': -159.78,
#   'Max Temp': 71.6,
#   'Humidity': 56,
#   'Cloudiness': 100,
#   'Wind Speed': 4.7,
#   'Country': 'CK',
#   'Date': '2020-07-31 01:12:14',
#   'Weather Condition': 'overcast clouds'},
#  {'City': 'Butaritari',
#   'Lat': 3.07,
#   'Lng': 172.79,
#   'Max Temp': 82.94,
#   'Humidity': 74,
#   'Cloudiness': 91,
#   'Wind Speed': 8.99,
#   'Country': 'KI',
#   'Date': '2020-07-31 01:13:32',
#   'Weather Condition': 'light rain'},
#  {'City': 'Busselton',
#   'Lat': -33.65,
#   'Lng': 115.33,
#   'Max Temp': 52,
#   'Humidity': 100,
#   'Cloudiness': 14,
#   'Wind Speed': 3.69,
#   'Country': 'AU',
#   'Date': '2020-07-31 01:13:32',
#   'Weather Condition': 'few clouds'},
#  {'City': 'Yeppoon',
#   'Lat': -23.13,
#   'Lng': 150.73,
#   'Max Temp': 69.8,
#   'Humidity': 46,
#   'Cloudiness': 37,
#   'Wind Speed': 13.87,
#   'Country': 'AU',
#   'Date': '2020-07-31 01:13:32',
#   'Weather Condition': 'scattered clouds'},
#  {'City': 'Vila Do Maio',
#   'Lat': 15.13,
#   'Lng': -23.22,
#   'Max Temp': 78.8,
#   'Humidity': 74,
#   'Cloudiness': 75,
#   'Wind Speed': 11.41,
#   'Country': 'CV',
#   'Date': '2020-07-31 01:13:32',
#   'Weather Condition': 'broken clouds'},
#  {'City': 'Albany',
#   'Lat': 42.6,
#   'Lng': -73.97,
#   'Max Temp': 77,
#   'Humidity': 57,
#   'Cloudiness': 61,
#   'Wind Speed': 1.99,
#   'Country': 'US',
#   'Date': '2020-07-31 01:13:32',
#   'Weather Condition': 'broken clouds'},
#  {'City': 'Wangaratta',
#   'Lat': -36.37,
#   'Lng': 146.33,
#   'Max Temp': 51.01,
#   'Humidity': 75,
#   'Cloudiness': 0,
#   'Wind Speed': 3.36,
#   'Country': 'AU',
#   'Date': '2020-07-31 01:13:32',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Hasaki',
#   'Lat': 35.73,
#   'Lng': 140.83,
#   'Max Temp': 77,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 2.24,
#   'Country': 'JP',
#   'Date': '2020-07-31 01:13:32',
#   'Weather Condition': 'shower rain'},
#  {'City': 'Okhotsk',
#   'Lat': 59.38,
#   'Lng': 143.3,
#   'Max Temp': 64.74,
#   'Humidity': 48,
#   'Cloudiness': 0,
#   'Wind Speed': 2.19,
#   'Country': 'RU',
#   'Date': '2020-07-31 01:13:33',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Fortuna',
#   'Lat': 40.6,
#   'Lng': -124.16,
#   'Max Temp': 66,
#   'Humidity': 82,
#   'Cloudiness': 3,
#   'Wind Speed': 3,
#   'Country': 'US',
#   'Date': '2020-07-31 01:18:58',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Warmbad',
#   'Lat': -28.45,
#   'Lng': 18.73,
#   'Max Temp': 57.04,
#   'Humidity': 34,
#   'Cloudiness': 0,
#   'Wind Speed': 8.66,
#   'Country': 'NA',
#   'Date': '2020-07-31 01:18:59',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Kysyl-Syr',
#   'Lat': 63.9,
#   'Lng': 122.76,
#   'Max Temp': 69.6,
#   'Humidity': 51,
#   'Cloudiness': 0,
#   'Wind Speed': 4.36,
#   'Country': 'RU',
#   'Date': '2020-07-31 01:18:59',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Kaitangata',
#   'Lat': -46.28,
#   'Lng': 169.85,
#   'Max Temp': 57,
#   'Humidity': 65,
#   'Cloudiness': 82,
#   'Wind Speed': 4,
#   'Country': 'NZ',
#   'Date': '2020-07-31 01:18:59',
#   'Weather Condition': 'broken clouds'},
#  {'City': 'Pevek',
#   'Lat': 69.7,
#   'Lng': 170.31,
#   'Max Temp': 36.19,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 9.4,
#   'Country': 'RU',
#   'Date': '2020-07-31 01:18:59',
#   'Weather Condition': 'light rain'},
#  {'City': 'Bethel',
#   'Lat': 41.37,
#   'Lng': -73.41,
#   'Max Temp': 75.2,
#   'Humidity': 88,
#   'Cloudiness': 1,
#   'Wind Speed': 4.09,
#   'Country': 'US',
#   'Date': '2020-07-31 01:09:26',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Tefe',
#   'Lat': -3.35,
#   'Lng': -64.71,
#   'Max Temp': 73.81,
#   'Humidity': 60,
#   'Cloudiness': 0,
#   'Wind Speed': 1.77,
#   'Country': 'BR',
#   'Date': '2020-07-31 01:13:33',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Khatanga',
#   'Lat': 71.97,
#   'Lng': 102.5,
#   'Max Temp': 68.02,
#   'Humidity': 39,
#   'Cloudiness': 1,
#   'Wind Speed': 14.56,
#   'Country': 'RU',
#   'Date': '2020-07-31 01:13:33',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Rikitea',
#   'Lat': -23.12,
#   'Lng': -134.97,
#   'Max Temp': 73.31,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 11.05,
#   'Country': 'PF',
#   'Date': '2020-07-31 01:13:33',
#   'Weather Condition': 'overcast clouds'},
#  {'City': 'Ranau',
#   'Lat': 5.95,
#   'Lng': 116.66,
#   'Max Temp': 78.8,
#   'Humidity': 88,
#   'Cloudiness': 20,
#   'Wind Speed': 2.24,
#   'Country': 'MY',
#   'Date': '2020-07-31 01:11:15',
#   'Weather Condition': 'few clouds'},
#  {'City': 'Ribeira Grande',
#   'Lat': 38.52,
#   'Lng': -28.7,
#   'Max Temp': 70.12,
#   'Humidity': 74,
#   'Cloudiness': 13,
#   'Wind Speed': 11.95,
#   'Country': 'PT',
#   'Date': '2020-07-31 01:13:34',
#   'Weather Condition': 'few clouds'},
#  {'City': 'Padrauna',
#   'Lat': 26.9,
#   'Lng': 83.98,
#   'Max Temp': 78.8,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 6.93,
#   'Country': 'IN',
#   'Date': '2020-07-31 01:18:59',
#   'Weather Condition': 'thunderstorm with light rain'},
#  {'City': 'Cape Town',
#   'Lat': -33.93,
#   'Lng': 18.42,
#   'Max Temp': 50,
#   'Humidity': 87,
#   'Cloudiness': 0,
#   'Wind Speed': 3.36,
#   'Country': 'ZA',
#   'Date': '2020-07-31 01:14:14',
#   'Weather Condition': 'clear sky'},
#  {'City': 'La Ronge',
#   'Lat': 55.1,
#   'Lng': -105.28,
#   'Max Temp': 75.2,
#   'Humidity': 60,
#   'Cloudiness': 75,
#   'Wind Speed': 9.17,
#   'Country': 'CA',
#   'Date': '2020-07-31 01:19:00',
#   'Weather Condition': 'broken clouds'},
#  {'City': 'Atuona',
#   'Lat': -9.8,
#   'Lng': -139.03,
#   'Max Temp': 79,
#   'Humidity': 73,
#   'Cloudiness': 28,
#   'Wind Speed': 16.49,
#   'Country': 'PF',
#   'Date': '2020-07-31 01:19:00',
#   'Weather Condition': 'scattered clouds'},
#  {'City': 'Itaqui',
#   'Lat': -29.13,
#   'Lng': -56.55,
#   'Max Temp': 49.51,
#   'Humidity': 93,
#   'Cloudiness': 0,
#   'Wind Speed': 7.09,
#   'Country': 'BR',
#   'Date': '2020-07-31 01:19:00',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Ancud',
#   'Lat': -41.87,
#   'Lng': -73.82,
#   'Max Temp': 48,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 11.41,
#   'Country': 'CL',
#   'Date': '2020-07-31 01:19:00',
#   'Weather Condition': 'overcast clouds'},
#  {'City': 'Jamestown',
#   'Lat': 42.1,
#   'Lng': -79.24,
#   'Max Temp': 71.6,
#   'Humidity': 60,
#   'Cloudiness': 1,
#   'Wind Speed': 3.36,
#   'Country': 'US',
#   'Date': '2020-07-31 01:13:34',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Mumbwa',
#   'Lat': -14.98,
#   'Lng': 27.06,
#   'Max Temp': 53.82,
#   'Humidity': 62,
#   'Cloudiness': 0,
#   'Wind Speed': 4.63,
#   'Country': 'ZM',
#   'Date': '2020-07-31 01:13:34',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Saldanha',
#   'Lat': -33.01,
#   'Lng': 17.94,
#   'Max Temp': 48.2,
#   'Humidity': 87,
#   'Cloudiness': 0,
#   'Wind Speed': 3.36,
#   'Country': 'ZA',
#   'Date': '2020-07-31 01:13:34',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Port Elizabeth',
#   'Lat': -33.92,
#   'Lng': 25.57,
#   'Max Temp': 53.6,
#   'Humidity': 87,
#   'Cloudiness': 0,
#   'Wind Speed': 5.82,
#   'Country': 'ZA',
#   'Date': '2020-07-31 01:13:35',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Provideniya',
#   'Lat': 64.38,
#   'Lng': -173.3,
#   'Max Temp': 50,
#   'Humidity': 76,
#   'Cloudiness': 75,
#   'Wind Speed': 15.66,
#   'Country': 'RU',
#   'Date': '2020-07-31 01:13:35',
#   'Weather Condition': 'broken clouds'},
#  {'City': 'Barrow',
#   'Lat': 71.29,
#   'Lng': -156.79,
#   'Max Temp': 37.4,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 8.05,
#   'Country': 'US',
#   'Date': '2020-07-31 01:10:01',
#   'Weather Condition': 'overcast clouds'},
#  {'City': 'Nanortalik',
#   'Lat': 60.14,
#   'Lng': -45.24,
#   'Max Temp': 43.63,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 5.32,
#   'Country': 'GL',
#   'Date': '2020-07-31 01:13:35',
#   'Weather Condition': 'overcast clouds'},
#  {'City': 'Turek',
#   'Lat': 52.02,
#   'Lng': 18.5,
#   'Max Temp': 55,
#   'Humidity': 85,
#   'Cloudiness': 0,
#   'Wind Speed': 2.42,
#   'Country': 'PL',
#   'Date': '2020-07-31 01:13:35',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Lasa',
#   'Lat': 46.62,
#   'Lng': 10.7,
#   'Max Temp': 64,
#   'Humidity': 93,
#   'Cloudiness': 20,
#   'Wind Speed': 4.7,
#   'Country': 'IT',
#   'Date': '2020-07-31 01:13:35',
#   'Weather Condition': 'few clouds'},
#  {'City': 'Hirara',
#   'Lat': 24.8,
#   'Lng': 125.28,
#   'Max Temp': 89.6,
#   'Humidity': 70,
#   'Cloudiness': 75,
#   'Wind Speed': 14.99,
#   'Country': 'JP',
#   'Date': '2020-07-31 01:13:35',
#   'Weather Condition': 'broken clouds'},
#  {'City': 'Arlit',
#   'Lat': 18.74,
#   'Lng': 7.39,
#   'Max Temp': 93.65,
#   'Humidity': 12,
#   'Cloudiness': 6,
#   'Wind Speed': 4.61,
#   'Country': 'NE',
#   'Date': '2020-07-31 01:13:35',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Olenino',
#   'Lat': 56.21,
#   'Lng': 33.49,
#   'Max Temp': 49.41,
#   'Humidity': 97,
#   'Cloudiness': 40,
#   'Wind Speed': 7.34,
#   'Country': 'RU',
#   'Date': '2020-07-31 01:13:35',
#   'Weather Condition': 'scattered clouds'},
#  {'City': 'Mar Del Plata',
#   'Lat': -38,
#   'Lng': -57.56,
#   'Max Temp': 46.99,
#   'Humidity': 87,
#   'Cloudiness': 0,
#   'Wind Speed': 13.87,
#   'Country': 'AR',
#   'Date': '2020-07-31 01:13:35',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Murgab',
#   'Lat': 37.5,
#   'Lng': 61.97,
#   'Max Temp': 82.4,
#   'Humidity': 45,
#   'Cloudiness': 40,
#   'Wind Speed': 11.41,
#   'Country': 'TM',
#   'Date': '2020-07-31 01:13:35',
#   'Weather Condition': 'scattered clouds'},
#  {'City': 'Katangli',
#   'Lat': 51.71,
#   'Lng': 143.23,
#   'Max Temp': 57.22,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 9.44,
#   'Country': 'RU',
#   'Date': '2020-07-31 01:13:36',
#   'Weather Condition': 'overcast clouds'},
#  {'City': 'Tazovskiy',
#   'Lat': 67.47,
#   'Lng': 78.7,
#   'Max Temp': 53.35,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 6.73,
#   'Country': 'RU',
#   'Date': '2020-07-31 01:13:36',
#   'Weather Condition': 'light rain'},
#  {'City': 'Moose Factory',
#   'Lat': 51.26,
#   'Lng': -80.61,
#   'Max Temp': 71.6,
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 2.24,
#   'Country': 'CA',
#   'Date': '2020-07-31 01:13:36',
#   'Weather Condition': 'few clouds'},
#  {'City': 'Tasiilaq',
#   'Lat': 65.61,
#   'Lng': -37.64,
#   'Max Temp': 44.6,
#   'Humidity': 70,
#   'Cloudiness': 8,
#   'Wind Speed': 3.71,
#   'Country': 'GL',
#   'Date': '2020-07-31 01:13:36',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Asino',
#   'Lat': 57,
#   'Lng': 86.15,
#   'Max Temp': 56.25,
#   'Humidity': 89,
#   'Cloudiness': 0,
#   'Wind Speed': 4,
#   'Country': 'RU',
#   'Date': '2020-07-31 01:13:36',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Tautira',
#   'Lat': -17.73,
#   'Lng': -149.15,
#   'Max Temp': 82.4,
#   'Humidity': 74,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Country': 'PF',
#   'Date': '2020-07-31 01:13:36',
#   'Weather Condition': 'broken clouds'},
#  {'City': 'Norman Wells',
#   'Lat': 65.28,
#   'Lng': -126.83,
#   'Max Temp': 75.2,
#   'Humidity': 50,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Country': 'CA',
#   'Date': '2020-07-31 01:12:13',
#   'Weather Condition': 'scattered clouds'},
#  {'City': 'Yar-Sale',
#   'Lat': 66.83,
#   'Lng': 70.83,
#   'Max Temp': 54.93,
#   'Humidity': 77,
#   'Cloudiness': 0,
#   'Wind Speed': 4.18,
#   'Country': 'RU',
#   'Date': '2020-07-31 01:13:36',
#   'Weather Condition': 'clear sky'},
#  {'City': 'El Naranjo',
#   'Lat': 21.47,
#   'Lng': -98.6,
#   'Max Temp': 79.36,
#   'Humidity': 87,
#   'Cloudiness': 94,
#   'Wind Speed': 4.65,
#   'Country': 'MX',
#   'Date': '2020-07-31 01:13:36',
#   'Weather Condition': 'moderate rain'},
#  {'City': 'Luderitz',
#   'Lat': -26.65,
#   'Lng': 15.16,
#   'Max Temp': 78.8,
#   'Humidity': 15,
#   'Cloudiness': 0,
#   'Wind Speed': 16.11,
#   'Country': 'NA',
#   'Date': '2020-07-31 01:13:36',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Chuy',
#   'Lat': -33.7,
#   'Lng': -53.46,
#   'Max Temp': 45.63,
#   'Humidity': 88,
#   'Cloudiness': 0,
#   'Wind Speed': 8.59,
#   'Country': 'UY',
#   'Date': '2020-07-31 01:13:36',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Berezna',
#   'Lat': 51.57,
#   'Lng': 31.78,
#   'Max Temp': 57.78,
#   'Humidity': 92,
#   'Cloudiness': 97,
#   'Wind Speed': 5.44,
#   'Country': 'UA',
#   'Date': '2020-07-31 01:13:37',
#   'Weather Condition': 'overcast clouds'},
#  {'City': 'Trang',
#   'Lat': 7.5,
#   'Lng': 99.5,
#   'Max Temp': 77,
#   'Humidity': 100,
#   'Cloudiness': 20,
#   'Wind Speed': 2.24,
#   'Country': 'TH',
#   'Date': '2020-07-31 01:13:37',
#   'Weather Condition': 'few clouds'},
#  {'City': 'Komsomolets',
#   'Lat': 53.75,
#   'Lng': 62.07,
#   'Max Temp': 61.93,
#   'Humidity': 87,
#   'Cloudiness': 11,
#   'Wind Speed': 8.08,
#   'Country': 'KZ',
#   'Date': '2020-07-31 01:13:37',
#   'Weather Condition': 'few clouds'},
#  {'City': 'Weyburn',
#   'Lat': 49.67,
#   'Lng': -103.85,
#   'Max Temp': 91,
#   'Humidity': 44,
#   'Cloudiness': 0,
#   'Wind Speed': 5.01,
#   'Country': 'CA',
#   'Date': '2020-07-31 01:10:24',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Port Macquarie',
#   'Lat': -31.43,
#   'Lng': 152.92,
#   'Max Temp': 61,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 3,
#   'Country': 'AU',
#   'Date': '2020-07-31 01:08:43',
#   'Weather Condition': 'light rain'},
#  {'City': 'Kodiak',
#   'Lat': 57.79,
#   'Lng': -152.41,
#   'Max Temp': 62.6,
#   'Humidity': 67,
#   'Cloudiness': 75,
#   'Wind Speed': 17.22,
#   'Country': 'US',
#   'Date': '2020-07-31 01:13:37',
#   'Weather Condition': 'broken clouds'},
#  {'City': 'Caravelas',
#   'Lat': -17.71,
#   'Lng': -39.25,
#   'Max Temp': 71.37,
#   'Humidity': 80,
#   'Cloudiness': 0,
#   'Wind Speed': 7.14,
#   'Country': 'BR',
#   'Date': '2020-07-31 01:13:37',
#   'Weather Condition': 'clear sky'},
#  {'City': 'New Norfolk',
#   'Lat': -42.78,
#   'Lng': 147.06,
#   'Max Temp': 55,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 3,
#   'Country': 'AU',
#   'Date': '2020-07-31 01:13:37',
#   'Weather Condition': 'overcast clouds'},
#  {'City': 'Sernur',
#   'Lat': 56.93,
#   'Lng': 49.15,
#   'Max Temp': 55.83,
#   'Humidity': 93,
#   'Cloudiness': 38,
#   'Wind Speed': 7.83,
#   'Country': 'RU',
#   'Date': '2020-07-31 01:13:37',
#   'Weather Condition': 'scattered clouds'},
#  {'City': 'Saskylakh',
#   'Lat': 71.92,
#   'Lng': 114.08,
#   'Max Temp': 61.63,
#   'Humidity': 57,
#   'Cloudiness': 0,
#   'Wind Speed': 3.62,
#   'Country': 'RU',
#   'Date': '2020-07-31 01:13:37',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Bambous Virieux',
#   'Lat': -20.34,
#   'Lng': 57.76,
#   'Max Temp': 69.8,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 4.7,
#   'Country': 'MU',
#   'Date': '2020-07-31 01:13:38',
#   'Weather Condition': 'broken clouds'},
#  {'City': 'Tias',
#   'Lat': 28.96,
#   'Lng': -13.64,
#   'Max Temp': 73.4,
#   'Humidity': 73,
#   'Cloudiness': 90,
#   'Wind Speed': 11.41,
#   'Country': 'ES',
#   'Date': '2020-07-31 01:13:38',
#   'Weather Condition': 'overcast clouds'},
#  {'City': 'Coruripe',
#   'Lat': -10.13,
#   'Lng': -36.18,
#   'Max Temp': 72.73,
#   'Humidity': 85,
#   'Cloudiness': 19,
#   'Wind Speed': 10.63,
#   'Country': 'BR',
#   'Date': '2020-07-31 01:13:11',
#   'Weather Condition': 'light rain'},
#  {'City': 'Bilibino',
#   'Lat': 68.05,
#   'Lng': 166.44,
#   'Max Temp': 52.2,
#   'Humidity': 59,
#   'Cloudiness': 100,
#   'Wind Speed': 5.23,
#   'Country': 'RU',
#   'Date': '2020-07-31 01:13:38',
#   'Weather Condition': 'overcast clouds'},
#  {'City': 'Umkomaas',
#   'Lat': -30.21,
#   'Lng': 30.8,
#   'Max Temp': 68,
#   'Humidity': 91,
#   'Cloudiness': 9,
#   'Wind Speed': 7.58,
#   'Country': 'ZA',
#   'Date': '2020-07-31 01:13:38',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Gewane',
#   'Lat': 10.17,
#   'Lng': 40.65,
#   'Max Temp': 74.07,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 1.92,
#   'Country': 'ET',
#   'Date': '2020-07-31 01:13:38',
#   'Weather Condition': 'heavy intensity rain'},
#  {'City': 'Saint George',
#   'Lat': 37.1,
#   'Lng': -113.58,
#   'Max Temp': 108,
#   'Humidity': 8,
#   'Cloudiness': 1,
#   'Wind Speed': 10.29,
#   'Country': 'US',
#   'Date': '2020-07-31 01:11:03',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Dzerzhinskoye',
#   'Lat': 56.83,
#   'Lng': 95.23,
#   'Max Temp': 59.86,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 8.59,
#   'Country': 'RU',
#   'Date': '2020-07-31 01:13:38',
#   'Weather Condition': 'overcast clouds'},
#  {'City': 'Guerrero Negro',
#   'Lat': 27.98,
#   'Lng': -114.06,
#   'Max Temp': 75.13,
#   'Humidity': 67,
#   'Cloudiness': 0,
#   'Wind Speed': 15.61,
#   'Country': 'MX',
#   'Date': '2020-07-31 01:13:38',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Bredasdorp',
#   'Lat': -34.53,
#   'Lng': 20.04,
#   'Max Temp': 50,
#   'Humidity': 87,
#   'Cloudiness': 0,
#   'Wind Speed': 5.82,
#   'Country': 'ZA',
#   'Date': '2020-07-31 01:13:38',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Seoul',
#   'Lat': 37.57,
#   'Lng': 126.98,
#   'Max Temp': 80.6,
#   'Humidity': 78,
#   'Cloudiness': 1,
#   'Wind Speed': 2.15,
#   'Country': 'KR',
#   'Date': '2020-07-31 01:09:12',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Manzhouli',
#   'Lat': 49.6,
#   'Lng': 117.43,
#   'Max Temp': 71.01,
#   'Humidity': 70,
#   'Cloudiness': 79,
#   'Wind Speed': 5.37,
#   'Country': 'CN',
#   'Date': '2020-07-31 01:13:38',
#   'Weather Condition': 'light rain'},
#  {'City': 'Castro',
#   'Lat': -24.79,
#   'Lng': -50.01,
#   'Max Temp': 48.34,
#   'Humidity': 90,
#   'Cloudiness': 62,
#   'Wind Speed': 8.93,
#   'Country': 'BR',
#   'Date': '2020-07-31 01:13:39',
#   'Weather Condition': 'broken clouds'},
#  {'City': 'Manicore',
#   'Lat': -5.81,
#   'Lng': -61.3,
#   'Max Temp': 73.4,
#   'Humidity': 88,
#   'Cloudiness': 22,
#   'Wind Speed': 1.5,
#   'Country': 'BR',
#   'Date': '2020-07-31 01:13:39',
#   'Weather Condition': 'few clouds'},
#  {'City': 'Bluff',
#   'Lat': -46.6,
#   'Lng': 168.33,
#   'Max Temp': 50.94,
#   'Humidity': 85,
#   'Cloudiness': 74,
#   'Wind Speed': 6.06,
#   'Country': 'NZ',
#   'Date': '2020-07-31 01:13:39',
#   'Weather Condition': 'broken clouds'},
#  {'City': 'Taoudenni',
#   'Lat': 22.68,
#   'Lng': -3.98,
#   'Max Temp': 91.36,
#   'Humidity': 35,
#   'Cloudiness': 14,
#   'Wind Speed': 11.83,
#   'Country': 'ML',
#   'Date': '2020-07-31 01:13:39',
#   'Weather Condition': 'few clouds'},
#  {'City': 'Maungaturoto',
#   'Lat': -36.1,
#   'Lng': 174.37,
#   'Max Temp': 59,
#   'Humidity': 78,
#   'Cloudiness': 85,
#   'Wind Speed': 4,
#   'Country': 'NZ',
#   'Date': '2020-07-31 01:13:39',
#   'Weather Condition': 'overcast clouds'},
#  {'City': 'Yellowknife',
#   'Lat': 62.46,
#   'Lng': -114.35,
#   'Max Temp': 71.6,
#   'Humidity': 43,
#   'Cloudiness': 40,
#   'Wind Speed': 14.99,
#   'Country': 'CA',
#   'Date': '2020-07-31 01:11:51',
#   'Weather Condition': 'scattered clouds'},
#  {'City': 'Hermanus',
#   'Lat': -34.42,
#   'Lng': 19.23,
#   'Max Temp': 46,
#   'Humidity': 94,
#   'Cloudiness': 0,
#   'Wind Speed': 4.36,
#   'Country': 'ZA',
#   'Date': '2020-07-31 01:13:39',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Kirakira',
#   'Lat': -10.45,
#   'Lng': 161.92,
#   'Max Temp': 83.26,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 3.33,
#   'Country': 'SB',
#   'Date': '2020-07-31 01:13:39',
#   'Weather Condition': 'light rain'},
#  {'City': 'Mataura',
#   'Lat': -46.19,
#   'Lng': 168.86,
#   'Max Temp': 56.48,
#   'Humidity': 65,
#   'Cloudiness': 100,
#   'Wind Speed': 2.91,
#   'Country': 'NZ',
#   'Date': '2020-07-31 01:11:37',
#   'Weather Condition': 'overcast clouds'},
#  {'City': 'Shieli',
#   'Lat': 44.17,
#   'Lng': 66.75,
#   'Max Temp': 73.11,
#   'Humidity': 33,
#   'Cloudiness': 23,
#   'Wind Speed': 8.03,
#   'Country': 'KZ',
#   'Date': '2020-07-31 01:13:39',
#   'Weather Condition': 'few clouds'},
#  {'City': 'Baykit',
#   'Lat': 61.67,
#   'Lng': 96.37,
#   'Max Temp': 65.44,
#   'Humidity': 66,
#   'Cloudiness': 89,
#   'Wind Speed': 4.41,
#   'Country': 'RU',
#   'Date': '2020-07-31 01:13:39',
#   'Weather Condition': 'overcast clouds'},
#  {'City': 'Klaksvik',
#   'Lat': 62.23,
#   'Lng': -6.59,
#   'Max Temp': 50,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 19.46,
#   'Country': 'FO',
#   'Date': '2020-07-31 01:13:39',
#   'Weather Condition': 'light rain'},
#  {'City': 'Auki',
#   'Lat': -8.77,
#   'Lng': 160.7,
#   'Max Temp': 83.25,
#   'Humidity': 75,
#   'Cloudiness': 39,
#   'Wind Speed': 3.8,
#   'Country': 'SB',
#   'Date': '2020-07-31 01:13:40',
#   'Weather Condition': 'light rain'},
#  {'City': 'Kyra',
#   'Lat': 49.58,
#   'Lng': 111.98,
#   'Max Temp': 62.17,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 1.03,
#   'Country': 'RU',
#   'Date': '2020-07-31 01:13:40',
#   'Weather Condition': 'overcast clouds'},
#  {'City': 'Bengkulu',
#   'Lat': -3.8,
#   'Lng': 102.27,
#   'Max Temp': 77.11,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 8.14,
#   'Country': 'ID',
#   'Date': '2020-07-31 01:11:59',
#   'Weather Condition': 'overcast clouds'},
#  {'City': 'Thompson',
#   'Lat': 55.74,
#   'Lng': -97.86,
#   'Max Temp': 66.2,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 3.36,
#   'Country': 'CA',
#   'Date': '2020-07-31 01:13:40',
#   'Weather Condition': 'light intensity shower rain'},
#  {'City': 'Glendive',
#   'Lat': 47.11,
#   'Lng': -104.71,
#   'Max Temp': 89.6,
#   'Humidity': 31,
#   'Cloudiness': 20,
#   'Wind Speed': 9.17,
#   'Country': 'US',
#   'Date': '2020-07-31 01:13:40',
#   'Weather Condition': 'thunderstorm'},
#  {'City': 'Atar',
#   'Lat': 20.52,
#   'Lng': -13.05,
#   'Max Temp': 87.73,
#   'Humidity': 47,
#   'Cloudiness': 100,
#   'Wind Speed': 7.99,
#   'Country': 'MR',
#   'Date': '2020-07-31 01:13:40',
#   'Weather Condition': 'moderate rain'},
#  {'City': 'Yulara',
#   'Lat': -25.24,
#   'Lng': 130.99,
#   'Max Temp': 57.2,
#   'Humidity': 24,
#   'Cloudiness': 0,
#   'Wind Speed': 12.75,
#   'Country': 'AU',
#   'Date': '2020-07-31 01:13:40',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Vao',
#   'Lat': -22.67,
#   'Lng': 167.48,
#   'Max Temp': 72.73,
#   'Humidity': 89,
#   'Cloudiness': 49,
#   'Wind Speed': 17.29,
#   'Country': 'NC',
#   'Date': '2020-07-31 01:13:40',
#   'Weather Condition': 'light rain'},
#  {'City': 'Nikolskoye',
#   'Lat': 59.7,
#   'Lng': 30.79,
#   'Max Temp': 57,
#   'Humidity': 87,
#   'Cloudiness': 40,
#   'Wind Speed': 4.47,
#   'Country': 'RU',
#   'Date': '2020-07-31 01:13:40',
#   'Weather Condition': 'scattered clouds'},
#  {'City': 'Roald',
#   'Lat': 62.58,
#   'Lng': 6.13,
#   'Max Temp': 57,
#   'Humidity': 100,
#   'Cloudiness': 2,
#   'Wind Speed': 2.24,
#   'Country': 'NO',
#   'Date': '2020-07-31 01:13:40',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Houma',
#   'Lat': 29.6,
#   'Lng': -90.72,
#   'Max Temp': 86,
#   'Humidity': 74,
#   'Cloudiness': 1,
#   'Wind Speed': 5.82,
#   'Country': 'US',
#   'Date': '2020-07-31 01:13:40',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Port Alfred',
#   'Lat': -33.59,
#   'Lng': 26.89,
#   'Max Temp': 55.9,
#   'Humidity': 83,
#   'Cloudiness': 2,
#   'Wind Speed': 7.92,
#   'Country': 'ZA',
#   'Date': '2020-07-31 01:08:59',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Alyangula',
#   'Lat': -13.85,
#   'Lng': 136.42,
#   'Max Temp': 77,
#   'Humidity': 53,
#   'Cloudiness': 0,
#   'Wind Speed': 6.93,
#   'Country': 'AU',
#   'Date': '2020-07-31 01:13:41',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Kaseda',
#   'Lat': 31.42,
#   'Lng': 130.32,
#   'Max Temp': 87.8,
#   'Humidity': 66,
#   'Cloudiness': 40,
#   'Wind Speed': 4.7,
#   'Country': 'JP',
#   'Date': '2020-07-31 01:13:41',
#   'Weather Condition': 'scattered clouds'},
#  {'City': 'Mgandu',
#   'Lat': -5.95,
#   'Lng': 34.13,
#   'Max Temp': 56.17,
#   'Humidity': 87,
#   'Cloudiness': 0,
#   'Wind Speed': 5.68,
#   'Country': 'TZ',
#   'Date': '2020-07-31 01:13:41',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Karla',
#   'Lat': 59.37,
#   'Lng': 24.93,
#   'Max Temp': 57.99,
#   'Humidity': 93,
#   'Cloudiness': 40,
#   'Wind Speed': 2.24,
#   'Country': 'EE',
#   'Date': '2020-07-31 01:13:41',
#   'Weather Condition': 'scattered clouds'},
#  {'City': 'Hithadhoo',
#   'Lat': -0.6,
#   'Lng': 73.08,
#   'Max Temp': 83.17,
#   'Humidity': 74,
#   'Cloudiness': 94,
#   'Wind Speed': 8.66,
#   'Country': 'MV',
#   'Date': '2020-07-31 01:13:41',
#   'Weather Condition': 'overcast clouds'},
#  {'City': 'Chitipa',
#   'Lat': -9.7,
#   'Lng': 33.27,
#   'Max Temp': 57.36,
#   'Humidity': 93,
#   'Cloudiness': 0,
#   'Wind Speed': 5.46,
#   'Country': 'MW',
#   'Date': '2020-07-31 01:13:41',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Hilo',
#   'Lat': 19.73,
#   'Lng': -155.09,
#   'Max Temp': 84.2,
#   'Humidity': 54,
#   'Cloudiness': 1,
#   'Wind Speed': 11.41,
#   'Country': 'US',
#   'Date': '2020-07-31 01:09:11',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Tuktoyaktuk',
#   'Lat': 69.45,
#   'Lng': -133.04,
#   'Max Temp': 66.2,
#   'Humidity': 63,
#   'Cloudiness': 75,
#   'Wind Speed': 3.36,
#   'Country': 'CA',
#   'Date': '2020-07-31 01:13:41',
#   'Weather Condition': 'broken clouds'},
#  {'City': 'Carnarvon',
#   'Lat': -24.87,
#   'Lng': 113.63,
#   'Max Temp': 62.6,
#   'Humidity': 88,
#   'Cloudiness': 0,
#   'Wind Speed': 11.41,
#   'Country': 'AU',
#   'Date': '2020-07-31 01:13:41',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Vicuna',
#   'Lat': -30.03,
#   'Lng': -70.71,
#   'Max Temp': 60.01,
#   'Humidity': 35,
#   'Cloudiness': 1,
#   'Wind Speed': 6.4,
#   'Country': 'CL',
#   'Date': '2020-07-31 01:13:41',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Puerto Ayora',
#   'Lat': -0.74,
#   'Lng': -90.35,
#   'Max Temp': 66.99,
#   'Humidity': 93,
#   'Cloudiness': 58,
#   'Wind Speed': 1.01,
#   'Country': 'EC',
#   'Date': '2020-07-31 01:13:42',
#   'Weather Condition': 'broken clouds'},
#  {'City': 'Vila Velha',
#   'Lat': -20.33,
#   'Lng': -40.29,
#   'Max Temp': 75,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 17.22,
#   'Country': 'BR',
#   'Date': '2020-07-31 01:13:42',
#   'Weather Condition': 'light rain'},
#  {'City': 'Labuhan',
#   'Lat': -6.88,
#   'Lng': 112.21,
#   'Max Temp': 77.45,
#   'Humidity': 76,
#   'Cloudiness': 0,
#   'Wind Speed': 11.61,
#   'Country': 'ID',
#   'Date': '2020-07-31 01:13:42',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Saint-Philippe',
#   'Lat': -21.36,
#   'Lng': 55.77,
#   'Max Temp': 68,
#   'Humidity': 77,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05,
#   'Country': 'RE',
#   'Date': '2020-07-31 01:13:42',
#   'Weather Condition': 'few clouds'},
#  {'City': 'Nemuro',
#   'Lat': 43.32,
#   'Lng': 145.57,
#   'Max Temp': 78.8,
#   'Humidity': 69,
#   'Cloudiness': 20,
#   'Wind Speed': 6.93,
#   'Country': 'JP',
#   'Date': '2020-07-31 01:13:42',
#   'Weather Condition': 'few clouds'},
#  {'City': 'Saint-Joseph',
#   'Lat': -21.37,
#   'Lng': 55.62,
#   'Max Temp': 68,
#   'Humidity': 77,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05,
#   'Country': 'RE',
#   'Date': '2020-07-31 01:13:42',
#   'Weather Condition': 'few clouds'},
#  {'City': 'Sola',
#   'Lat': -13.88,
#   'Lng': 167.55,
#   'Max Temp': 82.4,
#   'Humidity': 94,
#   'Cloudiness': 90,
#   'Wind Speed': 5.82,
#   'Country': 'VU',
#   'Date': '2020-07-31 01:13:42',
#   'Weather Condition': 'overcast clouds'},
#  {'City': 'Havre-Saint-Pierre',
#   'Lat': 50.23,
#   'Lng': -63.6,
#   'Max Temp': 60.8,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 11.41,
#   'Country': 'CA',
#   'Date': '2020-07-31 01:13:42',
#   'Weather Condition': 'mist'},
#  {'City': 'Marzuq',
#   'Lat': 14.4,
#   'Lng': 46.47,
#   'Max Temp': 78.4,
#   'Humidity': 60,
#   'Cloudiness': 100,
#   'Wind Speed': 3.56,
#   'Country': 'YE',
#   'Date': '2020-07-31 01:13:42',
#   'Weather Condition': 'overcast clouds'},
#  {'City': 'Hamilton',
#   'Lat': 39.18,
#   'Lng': -84.53,
#   'Max Temp': 70,
#   'Humidity': 94,
#   'Cloudiness': 90,
#   'Wind Speed': 6.93,
#   'Country': 'US',
#   'Date': '2020-07-31 01:10:08',
#   'Weather Condition': 'mist'},
#  {'City': 'Upernavik',
#   'Lat': 72.79,
#   'Lng': -56.15,
#   'Max Temp': 43.36,
#   'Humidity': 75,
#   'Cloudiness': 54,
#   'Wind Speed': 5.17,
#   'Country': 'GL',
#   'Date': '2020-07-31 01:13:42',
#   'Weather Condition': 'broken clouds'},
#  {'City': 'Qaanaaq',
#   'Lat': 77.48,
#   'Lng': -69.36,
#   'Max Temp': 41.68,
#   'Humidity': 66,
#   'Cloudiness': 0,
#   'Wind Speed': 4.97,
#   'Country': 'GL',
#   'Date': '2020-07-31 01:13:43',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Noumea',
#   'Lat': -22.28,
#   'Lng': 166.46,
#   'Max Temp': 75,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 5.82,
#   'Country': 'NC',
#   'Date': '2020-07-31 01:13:43',
#   'Weather Condition': 'overcast clouds'},
#  {'City': 'Boende',
#   'Lat': -0.22,
#   'Lng': 20.87,
#   'Max Temp': 73.69,
#   'Humidity': 72,
#   'Cloudiness': 0,
#   'Wind Speed': 0.65,
#   'Country': 'CD',
#   'Date': '2020-07-31 01:13:43',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Cravo Norte',
#   'Lat': 6.3,
#   'Lng': -70.2,
#   'Max Temp': 76.69,
#   'Humidity': 86,
#   'Cloudiness': 91,
#   'Wind Speed': 5.53,
#   'Country': 'CO',
#   'Date': '2020-07-31 01:13:43',
#   'Weather Condition': 'overcast clouds'},
#  {'City': 'Morondava',
#   'Lat': -20.28,
#   'Lng': 44.28,
#   'Max Temp': 65.53,
#   'Humidity': 75,
#   'Cloudiness': 0,
#   'Wind Speed': 14,
#   'Country': 'MG',
#   'Date': '2020-07-31 01:13:43',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Pasighat',
#   'Lat': 28.07,
#   'Lng': 95.33,
#   'Max Temp': 76.68,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 2.37,
#   'Country': 'IN',
#   'Date': '2020-07-31 01:13:43',
#   'Weather Condition': 'light rain'},
#  {'City': 'Nikolayevsk-Na-Amure',
#   'Lat': 53.14,
#   'Lng': 140.73,
#   'Max Temp': 64.65,
#   'Humidity': 71,
#   'Cloudiness': 100,
#   'Wind Speed': 4.36,
#   'Country': 'RU',
#   'Date': '2020-07-31 01:13:43',
#   'Weather Condition': 'overcast clouds'},
#  {'City': 'Makat',
#   'Lat': 47.65,
#   'Lng': 53.35,
#   'Max Temp': 74.12,
#   'Humidity': 47,
#   'Cloudiness': 0,
#   'Wind Speed': 7.25,
#   'Country': 'KZ',
#   'Date': '2020-07-31 01:13:43',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Badou',
#   'Lat': 7.58,
#   'Lng': 0.6,
#   'Max Temp': 69.73,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 3.29,
#   'Country': 'TG',
#   'Date': '2020-07-31 01:09:03',
#   'Weather Condition': 'overcast clouds'},
#  {'City': 'Iqaluit',
#   'Lat': 63.75,
#   'Lng': -68.51,
#   'Max Temp': 51.8,
#   'Humidity': 81,
#   'Cloudiness': 90,
#   'Wind Speed': 4.7,
#   'Country': 'CA',
#   'Date': '2020-07-31 01:13:43',
#   'Weather Condition': 'overcast clouds'},
#  {'City': 'Ontario',
#   'Lat': 34.06,
#   'Lng': -117.65,
#   'Max Temp': 98.6,
#   'Humidity': 17,
#   'Cloudiness': 20,
#   'Wind Speed': 12.75,
#   'Country': 'US',
#   'Date': '2020-07-31 01:09:24',
#   'Weather Condition': 'smoke'},
#  {'City': 'Camacha',
#   'Lat': 33.08,
#   'Lng': -16.33,
#   'Max Temp': 68,
#   'Humidity': 72,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Country': 'PT',
#   'Date': '2020-07-31 01:13:44',
#   'Weather Condition': 'broken clouds'},
#  {'City': 'Nayoro',
#   'Lat': 44.35,
#   'Lng': 142.46,
#   'Max Temp': 75.54,
#   'Humidity': 64,
#   'Cloudiness': 52,
#   'Wind Speed': 4.81,
#   'Country': 'JP',
#   'Date': '2020-07-31 01:13:44',
#   'Weather Condition': 'broken clouds'},
#  {'City': 'Mount Gambier',
#   'Lat': -37.83,
#   'Lng': 140.77,
#   'Max Temp': 46.4,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 5.82,
#   'Country': 'AU',
#   'Date': '2020-07-31 01:13:44',
#   'Weather Condition': 'overcast clouds'},
#  {'City': 'Port Blair',
#   'Lat': 11.67,
#   'Lng': 92.75,
#   'Max Temp': 81.43,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 16.11,
#   'Country': 'IN',
#   'Date': '2020-07-31 01:13:44',
#   'Weather Condition': 'light rain'},
#  {'City': 'Beloha',
#   'Lat': -25.17,
#   'Lng': 45.05,
#   'Max Temp': 59.41,
#   'Humidity': 87,
#   'Cloudiness': 2,
#   'Wind Speed': 4.47,
#   'Country': 'MG',
#   'Date': '2020-07-31 01:13:44',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Miyazu',
#   'Lat': 35.53,
#   'Lng': 135.18,
#   'Max Temp': 80.6,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 4.7,
#   'Country': 'JP',
#   'Date': '2020-07-31 01:13:44',
#   'Weather Condition': 'broken clouds'},
#  {'City': 'Sao Joao Da Barra',
#   'Lat': -21.64,
#   'Lng': -41.05,
#   'Max Temp': 68.34,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 19.8,
#   'Country': 'BR',
#   'Date': '2020-07-31 01:13:44',
#   'Weather Condition': 'light rain'},
#  {'City': 'Puerto Colombia',
#   'Lat': 10.99,
#   'Lng': -74.95,
#   'Max Temp': 78.8,
#   'Humidity': 83,
#   'Cloudiness': 20,
#   'Wind Speed': 4.7,
#   'Country': 'CO',
#   'Date': '2020-07-31 01:13:42',
#   'Weather Condition': 'few clouds'},
#  {'City': 'Constitucion',
#   'Lat': -35.33,
#   'Lng': -72.42,
#   'Max Temp': 51.06,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 3.36,
#   'Country': 'CL',
#   'Date': '2020-07-31 01:13:44',
#   'Weather Condition': 'overcast clouds'},
#  {'City': 'Rodrigues Alves',
#   'Lat': -7.74,
#   'Lng': -72.65,
#   'Max Temp': 75.56,
#   'Humidity': 68,
#   'Cloudiness': 29,
#   'Wind Speed': 2.93,
#   'Country': 'BR',
#   'Date': '2020-07-31 01:13:44',
#   'Weather Condition': 'scattered clouds'},
#  {'City': 'Oktyabrskiy',
#   'Lat': 54.48,
#   'Lng': 53.47,
#   'Max Temp': 61.14,
#   'Humidity': 93,
#   'Cloudiness': 76,
#   'Wind Speed': 4.47,
#   'Country': 'RU',
#   'Date': '2020-07-31 01:13:45',
#   'Weather Condition': 'broken clouds'},
#  {'City': 'Dikson',
#   'Lat': 73.51,
#   'Lng': 80.55,
#   'Max Temp': 53.98,
#   'Humidity': 69,
#   'Cloudiness': 100,
#   'Wind Speed': 11.95,
#   'Country': 'RU',
#   'Date': '2020-07-31 01:13:45',
#   'Weather Condition': 'overcast clouds'},
#  {'City': 'Amga',
#   'Lat': 60.9,
#   'Lng': 131.96,
#   'Max Temp': 69.93,
#   'Humidity': 37,
#   'Cloudiness': 38,
#   'Wind Speed': 5.28,
#   'Country': 'RU',
#   'Date': '2020-07-31 01:13:45',
#   'Weather Condition': 'scattered clouds'},
#  {'City': 'Goure',
#   'Lat': 13.98,
#   'Lng': 10.27,
#   'Max Temp': 80.19,
#   'Humidity': 68,
#   'Cloudiness': 94,
#   'Wind Speed': 15.55,
#   'Country': 'NE',
#   'Date': '2020-07-31 01:13:45',
#   'Weather Condition': 'overcast clouds'},
#  {'City': 'Etchoropo',
#   'Lat': 26.77,
#   'Lng': -109.67,
#   'Max Temp': 93,
#   'Humidity': 54,
#   'Cloudiness': 2,
#   'Wind Speed': 7,
#   'Country': 'MX',
#   'Date': '2020-07-31 01:13:45',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Milford',
#   'Lat': 41.22,
#   'Lng': -73.06,
#   'Max Temp': 78.8,
#   'Humidity': 69,
#   'Cloudiness': 1,
#   'Wind Speed': 9.1,
#   'Country': 'US',
#   'Date': '2020-07-31 01:13:45',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Wilmington',
#   'Lat': 34.23,
#   'Lng': -77.94,
#   'Max Temp': 82.99,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 12.75,
#   'Country': 'US',
#   'Date': '2020-07-31 01:09:40',
#   'Weather Condition': 'broken clouds'},
#  {'City': 'Peniche',
#   'Lat': 39.36,
#   'Lng': -9.38,
#   'Max Temp': 64.99,
#   'Humidity': 86,
#   'Cloudiness': 91,
#   'Wind Speed': 7,
#   'Country': 'PT',
#   'Date': '2020-07-31 01:13:45',
#   'Weather Condition': 'overcast clouds'},
#  {'City': 'Lebu',
#   'Lat': -37.62,
#   'Lng': -73.65,
#   'Max Temp': 49.6,
#   'Humidity': 92,
#   'Cloudiness': 66,
#   'Wind Speed': 12.21,
#   'Country': 'CL',
#   'Date': '2020-07-31 01:13:45',
#   'Weather Condition': 'broken clouds'},
#  {'City': 'Kawalu',
#   'Lat': -7.38,
#   'Lng': 108.21,
#   'Max Temp': 72.1,
#   'Humidity': 68,
#   'Cloudiness': 6,
#   'Wind Speed': 0.6,
#   'Country': 'ID',
#   'Date': '2020-07-31 01:13:45',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Poum',
#   'Lat': -20.23,
#   'Lng': 164.02,
#   'Max Temp': 73.51,
#   'Humidity': 90,
#   'Cloudiness': 21,
#   'Wind Speed': 12.06,
#   'Country': 'NC',
#   'Date': '2020-07-31 01:13:46',
#   'Weather Condition': 'few clouds'},
#  {'City': 'Kiunga',
#   'Lat': -6.12,
#   'Lng': 141.29,
#   'Max Temp': 78.22,
#   'Humidity': 76,
#   'Cloudiness': 98,
#   'Wind Speed': 5.84,
#   'Country': 'PG',
#   'Date': '2020-07-31 01:13:46',
#   'Weather Condition': 'overcast clouds'},
#  {'City': 'Torbay',
#   'Lat': 47.67,
#   'Lng': -52.73,
#   'Max Temp': 59,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 2.93,
#   'Country': 'CA',
#   'Date': '2020-07-31 01:13:46',
#   'Weather Condition': 'overcast clouds'},
#  {'City': 'Husavik',
#   'Lat': 66.04,
#   'Lng': -17.34,
#   'Max Temp': 48.2,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 2.24,
#   'Country': 'IS',
#   'Date': '2020-07-31 01:13:46',
#   'Weather Condition': 'overcast clouds'},
#  {'City': 'Kapaa',
#   'Lat': 22.08,
#   'Lng': -159.32,
#   'Max Temp': 82.4,
#   'Humidity': 65,
#   'Cloudiness': 75,
#   'Wind Speed': 16.11,
#   'Country': 'US',
#   'Date': '2020-07-31 01:13:46',
#   'Weather Condition': 'broken clouds'},
#  {'City': 'Kavieng',
#   'Lat': -2.57,
#   'Lng': 150.8,
#   'Max Temp': 85.39,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 9.75,
#   'Country': 'PG',
#   'Date': '2020-07-31 01:13:46',
#   'Weather Condition': 'light rain'},
#  {'City': 'Lodhran',
#   'Lat': 29.54,
#   'Lng': 71.63,
#   'Max Temp': 94.55,
#   'Humidity': 45,
#   'Cloudiness': 0,
#   'Wind Speed': 11.43,
#   'Country': 'PK',
#   'Date': '2020-07-31 01:13:46',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Bouna',
#   'Lat': 9.27,
#   'Lng': -3,
#   'Max Temp': 72.39,
#   'Humidity': 81,
#   'Cloudiness': 21,
#   'Wind Speed': 4.16,
#   'Country': 'CI',
#   'Date': '2020-07-31 01:13:46',
#   'Weather Condition': 'few clouds'},
#  {'City': 'Mingyue',
#   'Lat': 43.11,
#   'Lng': 128.92,
#   'Max Temp': 78.31,
#   'Humidity': 68,
#   'Cloudiness': 100,
#   'Wind Speed': 4.88,
#   'Country': 'CN',
#   'Date': '2020-07-31 01:13:46',
#   'Weather Condition': 'overcast clouds'},
#  {'City': 'Caucasia',
#   'Lat': 7.99,
#   'Lng': -75.19,
#   'Max Temp': 77.56,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 4.61,
#   'Country': 'CO',
#   'Date': '2020-07-31 01:13:46',
#   'Weather Condition': 'moderate rain'},
#  {'City': 'Hobyo',
#   'Lat': 5.35,
#   'Lng': 48.53,
#   'Max Temp': 77.47,
#   'Humidity': 79,
#   'Cloudiness': 99,
#   'Wind Speed': 23.33,
#   'Country': 'SO',
#   'Date': '2020-07-31 01:13:46',
#   'Weather Condition': 'overcast clouds'},
#  {'City': 'Salalah',
#   'Lat': 17.02,
#   'Lng': 54.09,
#   'Max Temp': 82.4,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 4.7,
#   'Country': 'OM',
#   'Date': '2020-07-31 01:13:47',
#   'Weather Condition': 'broken clouds'},
#  {'City': 'Axim',
#   'Lat': 4.87,
#   'Lng': -2.24,
#   'Max Temp': 74.71,
#   'Humidity': 84,
#   'Cloudiness': 99,
#   'Wind Speed': 8.34,
#   'Country': 'GH',
#   'Date': '2020-07-31 01:13:47',
#   'Weather Condition': 'overcast clouds'},
#  {'City': 'Bilma',
#   'Lat': 18.69,
#   'Lng': 12.92,
#   'Max Temp': 91.63,
#   'Humidity': 23,
#   'Cloudiness': 96,
#   'Wind Speed': 7.29,
#   'Country': 'NE',
#   'Date': '2020-07-31 01:13:47',
#   'Weather Condition': 'overcast clouds'},
#  {'City': 'Komsomolskiy',
#   'Lat': 40.43,
#   'Lng': 71.72,
#   'Max Temp': 78.8,
#   'Humidity': 41,
#   'Cloudiness': 97,
#   'Wind Speed': 4.7,
#   'Country': 'UZ',
#   'Date': '2020-07-31 01:13:47',
#   'Weather Condition': 'overcast clouds'},
#  {'City': 'Aklavik',
#   'Lat': 68.22,
#   'Lng': -135.01,
#   'Max Temp': 77,
#   'Humidity': 41,
#   'Cloudiness': 40,
#   'Wind Speed': 13.87,
#   'Country': 'CA',
#   'Date': '2020-07-31 01:13:47',
#   'Weather Condition': 'smoke'},
#  {'City': 'Kailua',
#   'Lat': 21.4,
#   'Lng': -157.74,
#   'Max Temp': 82,
#   'Humidity': 69,
#   'Cloudiness': 75,
#   'Wind Speed': 10.29,
#   'Country': 'US',
#   'Date': '2020-07-31 01:13:47',
#   'Weather Condition': 'broken clouds'},
#  {'City': 'Kerouane',
#   'Lat': 9.27,
#   'Lng': -9.02,
#   'Max Temp': 69.15,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 2.75,
#   'Country': 'GN',
#   'Date': '2020-07-31 01:13:47',
#   'Weather Condition': 'overcast clouds'},
#  {'City': 'Hobart',
#   'Lat': -42.88,
#   'Lng': 147.33,
#   'Max Temp': 55,
#   'Humidity': 66,
#   'Cloudiness': 75,
#   'Wind Speed': 10.29,
#   'Country': 'AU',
#   'Date': '2020-07-31 01:13:47',
#   'Weather Condition': 'broken clouds'},
#  {'City': 'Tuatapere',
#   'Lat': -46.13,
#   'Lng': 167.68,
#   'Max Temp': 54.93,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 3.13,
#   'Country': 'NZ',
#   'Date': '2020-07-31 01:13:47',
#   'Weather Condition': 'overcast clouds'},
#  {'City': 'Talnakh',
#   'Lat': 69.49,
#   'Lng': 88.4,
#   'Max Temp': 69.8,
#   'Humidity': 52,
#   'Cloudiness': 7,
#   'Wind Speed': 20.13,
#   'Country': 'RU',
#   'Date': '2020-07-31 01:13:47',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Dongying',
#   'Lat': 37.46,
#   'Lng': 118.49,
#   'Max Temp': 88.18,
#   'Humidity': 57,
#   'Cloudiness': 0,
#   'Wind Speed': 6.53,
#   'Country': 'CN',
#   'Date': '2020-07-31 01:13:48',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Meulaboh',
#   'Lat': 4.14,
#   'Lng': 96.13,
#   'Max Temp': 77.27,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 3.56,
#   'Country': 'ID',
#   'Date': '2020-07-31 01:13:48',
#   'Weather Condition': 'light rain'},
#  {'City': 'Lavrentiya',
#   'Lat': 65.58,
#   'Lng': -171,
#   'Max Temp': 46.22,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 9.89,
#   'Country': 'RU',
#   'Date': '2020-07-31 01:13:48',
#   'Weather Condition': 'overcast clouds'},
#  {'City': 'Sisimiut',
#   'Lat': 66.94,
#   'Lng': -53.67,
#   'Max Temp': 46.45,
#   'Humidity': 77,
#   'Cloudiness': 94,
#   'Wind Speed': 6.38,
#   'Country': 'GL',
#   'Date': '2020-07-31 01:13:48',
#   'Weather Condition': 'overcast clouds'},
#  {'City': 'Ola',
#   'Lat': 59.58,
#   'Lng': 151.28,
#   'Max Temp': 58.03,
#   'Humidity': 64,
#   'Cloudiness': 100,
#   'Wind Speed': 0.63,
#   'Country': 'RU',
#   'Date': '2020-07-31 01:13:48',
#   'Weather Condition': 'overcast clouds'},
#  {'City': 'Horta',
#   'Lat': 38.53,
#   'Lng': -28.63,
#   'Max Temp': 69.98,
#   'Humidity': 73,
#   'Cloudiness': 29,
#   'Wind Speed': 11.45,
#   'Country': 'PT',
#   'Date': '2020-07-31 01:13:48',
#   'Weather Condition': 'scattered clouds'},
#  {'City': 'Hokitika',
#   'Lat': -42.72,
#   'Lng': 170.97,
#   'Max Temp': 56.53,
#   'Humidity': 65,
#   'Cloudiness': 100,
#   'Wind Speed': 5.12,
#   'Country': 'NZ',
#   'Date': '2020-07-31 01:09:25',
#   'Weather Condition': 'overcast clouds'},
#  {'City': 'Udachnyy',
#   'Lat': 66.42,
#   'Lng': 112.4,
#   'Max Temp': 62.6,
#   'Humidity': 51,
#   'Cloudiness': 0,
#   'Wind Speed': 4.47,
#   'Country': 'RU',
#   'Date': '2020-07-31 01:13:48',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Karratha',
#   'Lat': -20.74,
#   'Lng': 116.85,
#   'Max Temp': 73.81,
#   'Humidity': 26,
#   'Cloudiness': 0,
#   'Wind Speed': 8.08,
#   'Country': 'AU',
#   'Date': '2020-07-31 01:13:49',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Oranjemund',
#   'Lat': -28.55,
#   'Lng': 16.43,
#   'Max Temp': 60.93,
#   'Humidity': 39,
#   'Cloudiness': 0,
#   'Wind Speed': 5.91,
#   'Country': 'NA',
#   'Date': '2020-07-31 01:13:49',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Nome',
#   'Lat': 64.5,
#   'Lng': -165.41,
#   'Max Temp': 55.4,
#   'Humidity': 76,
#   'Cloudiness': 75,
#   'Wind Speed': 10.29,
#   'Country': 'US',
#   'Date': '2020-07-31 01:13:49',
#   'Weather Condition': 'broken clouds'},
#  {'City': 'Bandarbeyla',
#   'Lat': 9.49,
#   'Lng': 50.81,
#   'Max Temp': 78.98,
#   'Humidity': 72,
#   'Cloudiness': 0,
#   'Wind Speed': 26.78,
#   'Country': 'SO',
#   'Date': '2020-07-31 01:13:49',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Zhigalovo',
#   'Lat': 54.81,
#   'Lng': 105.16,
#   'Max Temp': 67.21,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 2.21,
#   'Country': 'RU',
#   'Date': '2020-07-31 01:13:49',
#   'Weather Condition': 'overcast clouds'},
#  {'City': 'Shepsi',
#   'Lat': 44.04,
#   'Lng': 39.15,
#   'Max Temp': 74.17,
#   'Humidity': 78,
#   'Cloudiness': 1,
#   'Wind Speed': 3.44,
#   'Country': 'RU',
#   'Date': '2020-07-31 01:13:49',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Redmond',
#   'Lat': 47.67,
#   'Lng': -122.12,
#   'Max Temp': 89.01,
#   'Humidity': 47,
#   'Cloudiness': 0,
#   'Wind Speed': 1.01,
#   'Country': 'US',
#   'Date': '2020-07-31 01:13:31',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Genhe',
#   'Lat': 50.78,
#   'Lng': 121.52,
#   'Max Temp': 65.64,
#   'Humidity': 88,
#   'Cloudiness': 99,
#   'Wind Speed': 2.08,
#   'Country': 'CN',
#   'Date': '2020-07-31 01:13:49',
#   'Weather Condition': 'moderate rain'},
#  {'City': 'Progreso',
#   'Lat': 21.28,
#   'Lng': -89.67,
#   'Max Temp': 86,
#   'Humidity': 70,
#   'Cloudiness': 40,
#   'Wind Speed': 17.43,
#   'Country': 'MX',
#   'Date': '2020-07-31 01:13:49',
#   'Weather Condition': 'scattered clouds'},
#  {'City': 'Praia',
#   'Lat': 14.92,
#   'Lng': -23.51,
#   'Max Temp': 78.8,
#   'Humidity': 74,
#   'Cloudiness': 75,
#   'Wind Speed': 11.41,
#   'Country': 'CV',
#   'Date': '2020-07-31 01:13:49',
#   'Weather Condition': 'broken clouds'},
#  {'City': 'Codrington',
#   'Lat': -38.27,
#   'Lng': 141.97,
#   'Max Temp': 52.12,
#   'Humidity': 74,
#   'Cloudiness': 84,
#   'Wind Speed': 10.51,
#   'Country': 'AU',
#   'Date': '2020-07-31 01:13:49',
#   'Weather Condition': 'broken clouds'},
#  {'City': 'Cherskiy',
#   'Lat': 68.75,
#   'Lng': 161.3,
#   'Max Temp': 49.19,
#   'Humidity': 66,
#   'Cloudiness': 90,
#   'Wind Speed': 8.63,
#   'Country': 'RU',
#   'Date': '2020-07-31 01:13:50',
#   'Weather Condition': 'overcast clouds'},
#  {'City': 'Kuytun',
#   'Lat': 54.34,
#   'Lng': 101.5,
#   'Max Temp': 65.53,
#   'Humidity': 74,
#   'Cloudiness': 29,
#   'Wind Speed': 5.5,
#   'Country': 'RU',
#   'Date': '2020-07-31 01:13:50',
#   'Weather Condition': 'scattered clouds'},
#  {'City': 'Gravdal',
#   'Lat': 68.12,
#   'Lng': 13.5,
#   'Max Temp': 59.2,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 5.17,
#   'Country': 'NO',
#   'Date': '2020-07-31 01:13:50',
#   'Weather Condition': 'overcast clouds'},
#  {'City': 'Mancio Lima',
#   'Lat': -7.61,
#   'Lng': -72.9,
#   'Max Temp': 75.88,
#   'Humidity': 70,
#   'Cloudiness': 32,
#   'Wind Speed': 2.37,
#   'Country': 'BR',
#   'Date': '2020-07-31 01:13:50',
#   'Weather Condition': 'scattered clouds'},
#  {'City': 'Musoma',
#   'Lat': -1.5,
#   'Lng': 33.8,
#   'Max Temp': 71.01,
#   'Humidity': 61,
#   'Cloudiness': 21,
#   'Wind Speed': 6.67,
#   'Country': 'TZ',
#   'Date': '2020-07-31 01:13:50',
#   'Weather Condition': 'few clouds'},
#  {'City': 'Cabo San Lucas',
#   'Lat': 22.89,
#   'Lng': -109.91,
#   'Max Temp': 87.01,
#   'Humidity': 54,
#   'Cloudiness': 5,
#   'Wind Speed': 13.87,
#   'Country': 'MX',
#   'Date': '2020-07-31 01:13:13',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Sidney',
#   'Lat': -33.87,
#   'Lng': 151.21,
#   'Max Temp': 59,
#   'Humidity': 62,
#   'Cloudiness': 20,
#   'Wind Speed': 11.41,
#   'Country': 'AU',
#   'Date': '2020-07-31 01:12:40',
#   'Weather Condition': 'light rain'},
#  {'City': 'Candelaria',
#   'Lat': 13.93,
#   'Lng': 121.42,
#   'Max Temp': 77.18,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 0.36,
#   'Country': 'PH',
#   'Date': '2020-07-31 01:13:50',
#   'Weather Condition': 'light rain'},
#  {'City': 'Cayenne',
#   'Lat': 4.93,
#   'Lng': -52.33,
#   'Max Temp': 77,
#   'Humidity': 100,
#   'Cloudiness': 48,
#   'Wind Speed': 5.3,
#   'Country': 'GF',
#   'Date': '2020-07-31 01:13:50',
#   'Weather Condition': 'light rain'},
#  {'City': 'East London',
#   'Lat': -33.02,
#   'Lng': 27.91,
#   'Max Temp': 58.5,
#   'Humidity': 75,
#   'Cloudiness': 0,
#   'Wind Speed': 5.39,
#   'Country': 'ZA',
# ...
#   'Wind Speed': 4.7,
#   'Country': 'GE',
#   'Date': '2020-07-31 01:14:41',
#   'Weather Condition': 'broken clouds'},
#  {'City': 'Antalaha',
#   'Lat': -14.9,
#   'Lng': 50.28,
#   'Max Temp': 66.47,
#   'Humidity': 85,
#   'Cloudiness': 0,
#   'Wind Speed': 6.26,
#   'Country': 'MG',
#   'Date': '2020-07-31 01:14:41',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Tabuk',
#   'Lat': 17.42,
#   'Lng': 121.44,
#   'Max Temp': 77.77,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 5.97,
#   'Country': 'PH',
#   'Date': '2020-07-31 01:14:42',
#   'Weather Condition': 'light rain'},
#  {'City': 'Haines Junction',
#   'Lat': 60.75,
#   'Lng': -137.51,
#   'Max Temp': 74.95,
#   'Humidity': 37,
#   'Cloudiness': 0,
#   'Wind Speed': 8.21,
#   'Country': 'CA',
#   'Date': '2020-07-31 01:14:42',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Gopalganj',
#   'Lat': 26.47,
#   'Lng': 84.43,
#   'Max Temp': 81.5,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 6.98,
#   'Country': 'IN',
#   'Date': '2020-07-31 01:14:42',
#   'Weather Condition': 'overcast clouds'},
#  {'City': 'Ceska Ves',
#   'Lat': 50.26,
#   'Lng': 17.23,
#   'Max Temp': 57,
#   'Humidity': 66,
#   'Cloudiness': 100,
#   'Wind Speed': 2.13,
#   'Country': 'CZ',
#   'Date': '2020-07-31 01:14:42',
#   'Weather Condition': 'overcast clouds'},
#  {'City': 'Qaqortoq',
#   'Lat': 60.72,
#   'Lng': -46.03,
#   'Max Temp': 46.4,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 4.7,
#   'Country': 'GL',
#   'Date': '2020-07-31 01:14:42',
#   'Weather Condition': 'overcast clouds'},
#  {'City': 'Banjar',
#   'Lat': -8.19,
#   'Lng': 114.97,
#   'Max Temp': 78.8,
#   'Humidity': 88,
#   'Cloudiness': 40,
#   'Wind Speed': 13.87,
#   'Country': 'ID',
#   'Date': '2020-07-31 01:14:42',
#   'Weather Condition': 'scattered clouds'},
#  {'City': 'Sauda',
#   'Lat': 59.65,
#   'Lng': 6.35,
#   'Max Temp': 54,
#   'Humidity': 99,
#   'Cloudiness': 88,
#   'Wind Speed': 2.19,
#   'Country': 'NO',
#   'Date': '2020-07-31 01:14:43',
#   'Weather Condition': 'overcast clouds'},
#  {'City': 'Dumas',
#   'Lat': 35.87,
#   'Lng': -101.97,
#   'Max Temp': 84,
#   'Humidity': 47,
#   'Cloudiness': 1,
#   'Wind Speed': 19.57,
#   'Country': 'US',
#   'Date': '2020-07-31 01:14:43',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Bireun',
#   'Lat': 5.2,
#   'Lng': 96.7,
#   'Max Temp': 79.75,
#   'Humidity': 69,
#   'Cloudiness': 94,
#   'Wind Speed': 4.59,
#   'Country': 'ID',
#   'Date': '2020-07-31 01:14:43',
#   'Weather Condition': 'overcast clouds'},
#  {'City': 'Zabol',
#   'Lat': 32.25,
#   'Lng': 67.25,
#   'Max Temp': 66.09,
#   'Humidity': 24,
#   'Cloudiness': 0,
#   'Wind Speed': 2.28,
#   'Country': 'AF',
#   'Date': '2020-07-31 01:14:43',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Stange',
#   'Lat': 60.72,
#   'Lng': 11.19,
#   'Max Temp': 57.99,
#   'Humidity': 76,
#   'Cloudiness': 95,
#   'Wind Speed': 5.82,
#   'Country': 'NO',
#   'Date': '2020-07-31 01:14:43',
#   'Weather Condition': 'overcast clouds'},
#  {'City': 'Oistins',
#   'Lat': 13.07,
#   'Lng': -59.53,
#   'Max Temp': 82.4,
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 10.29,
#   'Country': 'BB',
#   'Date': '2020-07-31 01:14:43',
#   'Weather Condition': 'few clouds'},
#  {'City': 'Varnamo',
#   'Lat': 57.19,
#   'Lng': 14.04,
#   'Max Temp': 55.99,
#   'Humidity': 94,
#   'Cloudiness': 62,
#   'Wind Speed': 7,
#   'Country': 'SE',
#   'Date': '2020-07-31 01:14:44',
#   'Weather Condition': 'broken clouds'},
#  {'City': 'Pisco',
#   'Lat': -13.7,
#   'Lng': -76.22,
#   'Max Temp': 60.8,
#   'Humidity': 82,
#   'Cloudiness': 0,
#   'Wind Speed': 12.75,
#   'Country': 'PE',
#   'Date': '2020-07-31 01:14:44',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Quelimane',
#   'Lat': -17.88,
#   'Lng': 36.89,
#   'Max Temp': 64.4,
#   'Humidity': 93,
#   'Cloudiness': 0,
#   'Wind Speed': 3.33,
#   'Country': 'MZ',
#   'Date': '2020-07-31 01:14:44',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Nyeri',
#   'Lat': -0.42,
#   'Lng': 36.95,
#   'Max Temp': 57.9,
#   'Humidity': 91,
#   'Cloudiness': 81,
#   'Wind Speed': 4.05,
#   'Country': 'KE',
#   'Date': '2020-07-31 01:14:44',
#   'Weather Condition': 'broken clouds'},
#  {'City': 'Lake Havasu City',
#   'Lat': 34.48,
#   'Lng': -114.32,
#   'Max Temp': 117,
#   'Humidity': 6,
#   'Cloudiness': 1,
#   'Wind Speed': 8.1,
#   'Country': 'US',
#   'Date': '2020-07-31 01:14:44',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Bud',
#   'Lat': 39.45,
#   'Lng': -86.18,
#   'Max Temp': 68,
#   'Humidity': 98,
#   'Cloudiness': 99,
#   'Wind Speed': 9.6,
#   'Country': 'US',
#   'Date': '2020-07-31 01:14:44',
#   'Weather Condition': 'overcast clouds'},
#  {'City': 'Yanam',
#   'Lat': 16.73,
#   'Lng': 82.22,
#   'Max Temp': 84.2,
#   'Humidity': 79,
#   'Cloudiness': 40,
#   'Wind Speed': 4.7,
#   'Country': 'IN',
#   'Date': '2020-07-31 01:14:44',
#   'Weather Condition': 'scattered clouds'},
#  {'City': 'Punta Alta',
#   'Lat': -38.88,
#   'Lng': -62.07,
#   'Max Temp': 49.28,
#   'Humidity': 52,
#   'Cloudiness': 100,
#   'Wind Speed': 18.12,
#   'Country': 'AR',
#   'Date': '2020-07-31 01:14:45',
#   'Weather Condition': 'overcast clouds'},
#  {'City': 'Turukhansk',
#   'Lat': 65.82,
#   'Lng': 87.98,
#   'Max Temp': 65.62,
#   'Humidity': 69,
#   'Cloudiness': 100,
#   'Wind Speed': 17.85,
#   'Country': 'RU',
#   'Date': '2020-07-31 01:14:45',
#   'Weather Condition': 'overcast clouds'},
#  {'City': 'Deep River',
#   'Lat': 46.1,
#   'Lng': -77.5,
#   'Max Temp': 73.4,
#   'Humidity': 83,
#   'Cloudiness': 1,
#   'Wind Speed': 3.47,
#   'Country': 'CA',
#   'Date': '2020-07-31 01:14:45',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Lorengau',
#   'Lat': -2.02,
#   'Lng': 147.27,
#   'Max Temp': 86.22,
#   'Humidity': 67,
#   'Cloudiness': 100,
#   'Wind Speed': 11.9,
#   'Country': 'PG',
#   'Date': '2020-07-31 01:14:45',
#   'Weather Condition': 'overcast clouds'},
#  {'City': 'Barcelos',
#   'Lat': 41.54,
#   'Lng': -8.62,
#   'Max Temp': 66.99,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 1.12,
#   'Country': 'PT',
#   'Date': '2020-07-31 01:14:45',
#   'Weather Condition': 'broken clouds'},
#  {'City': 'Tymovskoye',
#   'Lat': 50.85,
#   'Lng': 142.66,
#   'Max Temp': 70.43,
#   'Humidity': 64,
#   'Cloudiness': 91,
#   'Wind Speed': 7.52,
#   'Country': 'RU',
#   'Date': '2020-07-31 01:14:46',
#   'Weather Condition': 'overcast clouds'},
#  {'City': 'Seminole',
#   'Lat': 28.71,
#   'Lng': -81.21,
#   'Max Temp': 87.8,
#   'Humidity': 55,
#   'Cloudiness': 40,
#   'Wind Speed': 3.36,
#   'Country': 'US',
#   'Date': '2020-07-31 01:12:46',
#   'Weather Condition': 'thunderstorm'},
#  {'City': 'Saint Anthony',
#   'Lat': 45.02,
#   'Lng': -93.22,
#   'Max Temp': 79,
#   'Humidity': 47,
#   'Cloudiness': 40,
#   'Wind Speed': 3.36,
#   'Country': 'US',
#   'Date': '2020-07-31 01:14:46',
#   'Weather Condition': 'scattered clouds'},
#  {'City': 'Izobilnyy',
#   'Lat': 45.37,
#   'Lng': 41.71,
#   'Max Temp': 66.2,
#   'Humidity': 48,
#   'Cloudiness': 0,
#   'Wind Speed': 2.24,
#   'Country': 'RU',
#   'Date': '2020-07-31 01:14:46',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Kastamonu',
#   'Lat': 41.5,
#   'Lng': 33.67,
#   'Max Temp': 55.81,
#   'Humidity': 88,
#   'Cloudiness': 0,
#   'Wind Speed': 1.12,
#   'Country': 'TR',
#   'Date': '2020-07-31 01:14:46',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Magadan',
#   'Lat': 59.57,
#   'Lng': 150.8,
#   'Max Temp': 58.19,
#   'Humidity': 60,
#   'Cloudiness': 100,
#   'Wind Speed': 2.75,
#   'Country': 'RU',
#   'Date': '2020-07-31 01:14:47',
#   'Weather Condition': 'overcast clouds'},
#  {'City': 'Sagua La Grande',
#   'Lat': 22.81,
#   'Lng': -80.08,
#   'Max Temp': 80.6,
#   'Humidity': 83,
#   'Cloudiness': 20,
#   'Wind Speed': 9.17,
#   'Country': 'CU',
#   'Date': '2020-07-31 01:14:47',
#   'Weather Condition': 'few clouds'},
#  {'City': 'Sokolka',
#   'Lat': 53.41,
#   'Lng': 23.5,
#   'Max Temp': 55.99,
#   'Humidity': 67,
#   'Cloudiness': 23,
#   'Wind Speed': 7.38,
#   'Country': 'PL',
#   'Date': '2020-07-31 01:14:47',
#   'Weather Condition': 'few clouds'},
#  {'City': 'Kingman',
#   'Lat': 35.19,
#   'Lng': -114.05,
#   'Max Temp': 107.6,
#   'Humidity': 8,
#   'Cloudiness': 1,
#   'Wind Speed': 9.17,
#   'Country': 'US',
#   'Date': '2020-07-31 01:11:52',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Ahipara',
#   'Lat': -35.17,
#   'Lng': 173.17,
#   'Max Temp': 59.94,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 14.29,
#   'Country': 'NZ',
#   'Date': '2020-07-31 01:14:47',
#   'Weather Condition': 'overcast clouds'},
#  {'City': 'Mazara Del Vallo',
#   'Lat': 37.66,
#   'Lng': 12.59,
#   'Max Temp': 82,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 2.24,
#   'Country': 'IT',
#   'Date': '2020-07-31 01:14:47',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Otjiwarongo',
#   'Lat': -20.46,
#   'Lng': 16.65,
#   'Max Temp': 49.98,
#   'Humidity': 44,
#   'Cloudiness': 0,
#   'Wind Speed': 12.01,
#   'Country': 'NA',
#   'Date': '2020-07-31 01:14:47',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Mihai Viteazu',
#   'Lat': 46.53,
#   'Lng': 23.75,
#   'Max Temp': 68,
#   'Humidity': 94,
#   'Cloudiness': 12,
#   'Wind Speed': 3.36,
#   'Country': 'RO',
#   'Date': '2020-07-31 01:14:47',
#   'Weather Condition': 'few clouds'},
#  {'City': 'Marsa Matruh',
#   'Lat': 31.35,
#   'Lng': 27.25,
#   'Max Temp': 73.4,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 7.45,
#   'Country': 'EG',
#   'Date': '2020-07-31 01:14:48',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Mackay',
#   'Lat': -21.15,
#   'Lng': 149.2,
#   'Max Temp': 70,
#   'Humidity': 64,
#   'Cloudiness': 39,
#   'Wind Speed': 16.11,
#   'Country': 'AU',
#   'Date': '2020-07-31 01:14:48',
#   'Weather Condition': 'scattered clouds'},
#  {'City': 'Talakan',
#   'Lat': 50.32,
#   'Lng': 130.37,
#   'Max Temp': 77.86,
#   'Humidity': 71,
#   'Cloudiness': 100,
#   'Wind Speed': 5.37,
#   'Country': 'RU',
#   'Date': '2020-07-31 01:14:48',
#   'Weather Condition': 'light rain'},
#  {'City': 'Eskil',
#   'Lat': 38.4,
#   'Lng': 33.41,
#   'Max Temp': 67.69,
#   'Humidity': 52,
#   'Cloudiness': 0,
#   'Wind Speed': 4.56,
#   'Country': 'TR',
#   'Date': '2020-07-31 01:14:48',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Delano',
#   'Lat': 35.77,
#   'Lng': -119.25,
#   'Max Temp': 100.4,
#   'Humidity': 16,
#   'Cloudiness': 1,
#   'Wind Speed': 4.7,
#   'Country': 'US',
#   'Date': '2020-07-31 01:14:48',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Margate',
#   'Lat': 51.38,
#   'Lng': 1.39,
#   'Max Temp': 68,
#   'Humidity': 83,
#   'Cloudiness': 0,
#   'Wind Speed': 1.01,
#   'Country': 'GB',
#   'Date': '2020-07-31 01:14:48',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Aksarka',
#   'Lat': 66.56,
#   'Lng': 67.8,
#   'Max Temp': 51.21,
#   'Humidity': 83,
#   'Cloudiness': 0,
#   'Wind Speed': 5.7,
#   'Country': 'RU',
#   'Date': '2020-07-31 01:14:48',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Koungou',
#   'Lat': -12.73,
#   'Lng': 45.2,
#   'Max Temp': 77,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 19.46,
#   'Country': 'YT',
#   'Date': '2020-07-31 01:14:49',
#   'Weather Condition': 'broken clouds'},
#  {'City': 'Mweka',
#   'Lat': -4.85,
#   'Lng': 21.57,
#   'Max Temp': 68.25,
#   'Humidity': 34,
#   'Cloudiness': 0,
#   'Wind Speed': 0.78,
#   'Country': 'CD',
#   'Date': '2020-07-31 01:14:49',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Lar',
#   'Lat': 26.2,
#   'Lng': 83.97,
#   'Max Temp': 83.19,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 5.97,
#   'Country': 'IN',
#   'Date': '2020-07-31 01:14:49',
#   'Weather Condition': 'overcast clouds'},
#  {'City': 'Harper',
#   'Lat': 4.38,
#   'Lng': -7.72,
#   'Max Temp': 75.18,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 7.2,
#   'Country': 'LR',
#   'Date': '2020-07-31 01:14:49',
#   'Weather Condition': 'overcast clouds'},
#  {'City': 'Setubal',
#   'Lat': 38.52,
#   'Lng': -8.89,
#   'Max Temp': 66.2,
#   'Humidity': 82,
#   'Cloudiness': 0,
#   'Wind Speed': 4.7,
#   'Country': 'PT',
#   'Date': '2020-07-31 01:14:49',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Ife',
#   'Lat': 7.47,
#   'Lng': 4.57,
#   'Max Temp': 70.77,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 4.18,
#   'Country': 'NG',
#   'Date': '2020-07-31 01:14:49',
#   'Weather Condition': 'overcast clouds'},
#  {'City': 'Vizianagaram',
#   'Lat': 18.12,
#   'Lng': 83.42,
#   'Max Temp': 80.6,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 2.24,
#   'Country': 'IN',
#   'Date': '2020-07-31 01:14:50',
#   'Weather Condition': 'mist'},
#  {'City': 'Sao Jose Da Coroa Grande',
#   'Lat': -8.9,
#   'Lng': -35.15,
#   'Max Temp': 73.27,
#   'Humidity': 86,
#   'Cloudiness': 37,
#   'Wind Speed': 10.47,
#   'Country': 'BR',
#   'Date': '2020-07-31 01:14:50',
#   'Weather Condition': 'light rain'},
#  {'City': 'Avera',
#   'Lat': 33.19,
#   'Lng': -82.53,
#   'Max Temp': 80.6,
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind Speed': 6.93,
#   'Country': 'US',
#   'Date': '2020-07-31 01:14:50',
#   'Weather Condition': 'scattered clouds'},
#  {'City': 'Flin Flon',
#   'Lat': 54.77,
#   'Lng': -101.86,
#   'Max Temp': 71.06,
#   'Humidity': 81,
#   'Cloudiness': 98,
#   'Wind Speed': 2.75,
#   'Country': 'CA',
#   'Date': '2020-07-31 01:14:50',
#   'Weather Condition': 'moderate rain'},
#  {'City': 'Sechura',
#   'Lat': -5.56,
#   'Lng': -80.82,
#   'Max Temp': 64,
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 13.02,
#   'Country': 'PE',
#   'Date': '2020-07-31 01:14:50',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Katobu',
#   'Lat': -4.94,
#   'Lng': 122.53,
#   'Max Temp': 81.45,
#   'Humidity': 64,
#   'Cloudiness': 43,
#   'Wind Speed': 5.17,
#   'Country': 'ID',
#   'Date': '2020-07-31 01:14:51',
#   'Weather Condition': 'scattered clouds'},
#  {'City': 'Simbahan',
#   'Lat': 6.3,
#   'Lng': 120.58,
#   'Max Temp': 83.7,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 15.46,
#   'Country': 'PH',
#   'Date': '2020-07-31 01:14:51',
#   'Weather Condition': 'moderate rain'},
#  {'City': 'Maputo',
#   'Lat': -25.97,
#   'Lng': 32.59,
#   'Max Temp': 64,
#   'Humidity': 84,
#   'Cloudiness': 17,
#   'Wind Speed': 5.99,
#   'Country': 'MZ',
#   'Date': '2020-07-31 01:14:51',
#   'Weather Condition': 'few clouds'},
#  {'City': 'Berlin',
#   'Lat': 52.52,
#   'Lng': 13.41,
#   'Max Temp': 63,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 1.12,
#   'Country': 'DE',
#   'Date': '2020-07-31 01:10:01',
#   'Weather Condition': 'overcast clouds'},
#  {'City': 'Agadez',
#   'Lat': 19.75,
#   'Lng': 10.25,
#   'Max Temp': 85.93,
#   'Humidity': 14,
#   'Cloudiness': 99,
#   'Wind Speed': 4.7,
#   'Country': 'NE',
#   'Date': '2020-07-31 01:14:51',
#   'Weather Condition': 'overcast clouds'},
#  {'City': 'Vanderhoof',
#   'Lat': 54.02,
#   'Lng': -124.02,
#   'Max Temp': 83.17,
#   'Humidity': 33,
#   'Cloudiness': 0,
#   'Wind Speed': 0.92,
#   'Country': 'CA',
#   'Date': '2020-07-31 01:14:51',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Talaya',
#   'Lat': 61.38,
#   'Lng': 152.75,
#   'Max Temp': 47.03,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 16.37,
#   'Country': 'RU',
#   'Date': '2020-07-31 01:14:51',
#   'Weather Condition': 'overcast clouds'},
#  {'City': 'Gradignan',
#   'Lat': 44.77,
#   'Lng': -0.61,
#   'Max Temp': 80.6,
#   'Humidity': 54,
#   'Cloudiness': 100,
#   'Wind Speed': 5.82,
#   'Country': 'FR',
#   'Date': '2020-07-31 01:14:51',
#   'Weather Condition': 'overcast clouds'},
#  {'City': 'Ciudad Bolivar',
#   'Lat': 8.12,
#   'Lng': -63.55,
#   'Max Temp': 83.37,
#   'Humidity': 68,
#   'Cloudiness': 0,
#   'Wind Speed': 2.21,
#   'Country': 'VE',
#   'Date': '2020-07-31 01:14:51',
#   'Weather Condition': 'light rain'},
#  {'City': 'Omboue',
#   'Lat': -1.57,
#   'Lng': 9.26,
#   'Max Temp': 71.91,
#   'Humidity': 83,
#   'Cloudiness': 99,
#   'Wind Speed': 6.89,
#   'Country': 'GA',
#   'Date': '2020-07-31 01:14:52',
#   'Weather Condition': 'overcast clouds'},
#  {'City': 'Boa Vista',
#   'Lat': 2.82,
#   'Lng': -60.67,
#   'Max Temp': 84.2,
#   'Humidity': 62,
#   'Cloudiness': 0,
#   'Wind Speed': 4.7,
#   'Country': 'BR',
#   'Date': '2020-07-31 01:11:50',
#   'Weather Condition': 'clear sky'},
#  {'City': 'Carmo Do Rio Claro',
#   'Lat': -20.97,
#   'Lng': -46.12,
#   'Max Temp': 62.31,
#   'Humidity': 79,
#   'Cloudiness': 72,
#   'Wind Speed': 6.78,
#   'Country': 'BR',
#   'Date': '2020-07-31 01:14:52',
#   'Weather Condition': 'broken clouds'},
#  {'City': 'Fort William',
#   'Lat': 56.82,
#   'Lng': -5.11,
#   'Max Temp': 53.01,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 5.59,
#   'Country': 'GB',
#   'Date': '2020-07-31 01:14:52',
#   'Weather Condition': 'overcast clouds'},
#  {'City': 'Ilinskiy',
#   'Lat': 55.62,
#   'Lng': 38.12,
#   'Max Temp': 57,
#   'Humidity': 82,
#   'Cloudiness': 99,
#   'Wind Speed': 6.71,
#   'Country': 'RU',
#   'Date': '2020-07-31 01:14:52',
#   'Weather Condition': 'overcast clouds'}]

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                    City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0            Georgetown   5.41  100.34     80.60        94          20
# 1       Arraial Do Cabo -22.97  -42.03     67.41        81         100
# 2          Punta Arenas -53.15  -70.92     35.60        93         100
# 3             Sinnamary   5.38  -52.95     78.57        80          17
# 4              Zarubino  42.63  131.09     74.05        78          81
# ..                  ...    ...     ...       ...       ...         ...
# 701              Omboue  -1.57    9.26     71.91        83          99
# 702           Boa Vista   2.82  -60.67     84.20        62           0
# 703  Carmo Do Rio Claro -20.97  -46.12     62.31        79          72
# 704        Fort William  56.82   -5.11     53.01        96         100
# 705            Ilinskiy  55.62   38.12     57.00        82          99
#
#      Wind Speed Country                 Date Weather Condition
# 0          2.24      MY  2020-07-31 01:09:04        few clouds
# 1         14.81      BR  2020-07-31 01:13:31   overcast clouds
# 2         14.99      CL  2020-07-31 01:13:31   overcast clouds
# 3          4.85      GF  2020-07-31 01:13:31        few clouds
# 4          4.72      RU  2020-07-31 01:13:31     broken clouds
# ..          ...     ...                  ...               ...
# 701        6.89      GA  2020-07-31 01:14:52   overcast clouds
# 702        4.70      BR  2020-07-31 01:11:50         clear sky
# 703        6.78      BR  2020-07-31 01:14:52     broken clouds
# 704        5.59      GB  2020-07-31 01:14:52   overcast clouds
# 705        6.71      RU  2020-07-31 01:14:52   overcast clouds
#
# [706 rows x 10 columns]

# %%
new_column_order = ["City", "Country", 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Weather Condition', 'Date']
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#                    City Country    Lat     Lng  Max Temp  Humidity  \
# 0            Georgetown      MY   5.41  100.34     80.60        94
# 1       Arraial Do Cabo      BR -22.97  -42.03     67.41        81
# 2          Punta Arenas      CL -53.15  -70.92     35.60        93
# 3             Sinnamary      GF   5.38  -52.95     78.57        80
# 4              Zarubino      RU  42.63  131.09     74.05        78
# ..                  ...     ...    ...     ...       ...       ...
# 701              Omboue      GA  -1.57    9.26     71.91        83
# 702           Boa Vista      BR   2.82  -60.67     84.20        62
# 703  Carmo Do Rio Claro      BR -20.97  -46.12     62.31        79
# 704        Fort William      GB  56.82   -5.11     53.01        96
# 705            Ilinskiy      RU  55.62   38.12     57.00        82
#
#      Cloudiness  Wind Speed Weather Condition                 Date
# 0            20        2.24        few clouds  2020-07-31 01:09:04
# 1           100       14.81   overcast clouds  2020-07-31 01:13:31
# 2           100       14.99   overcast clouds  2020-07-31 01:13:31
# 3            17        4.85        few clouds  2020-07-31 01:13:31
# 4            81        4.72     broken clouds  2020-07-31 01:13:31
# ..          ...         ...               ...                  ...
# 701          99        6.89   overcast clouds  2020-07-31 01:14:52
# 702           0        4.70         clear sky  2020-07-31 01:11:50
# 703          72        6.78     broken clouds  2020-07-31 01:14:52
# 704         100        5.59   overcast clouds  2020-07-31 01:14:52
# 705          99        6.71   overcast clouds  2020-07-31 01:14:52
#
# [706 rows x 10 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
